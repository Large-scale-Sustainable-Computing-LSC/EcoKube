# %% [markdown]
# # Kubernetes vs. Simulator Evaluation
#
# This notebook reproduces the final evaluation cycle combining the Kubernetes replay
# and the simulator runs. It loads the exported scheduling traces, harmonises the
# schema, computes summary metrics, and visualises the trade-offs across policies with
# Pareto-front analysis.
#
# The workflow follows the architecture notes in Chapter 5.3.2 of the design document:
#
# 1. Select the runs and fetch the traces.
# 2. Harmonise the per-job schema and enrich it with timing features.
# 3. Optionally pull contextual metrics (left as hooks for Prometheus integration).
# 4. Produce visual comparisons and Pareto-front inspection.

# %% [markdown]
# ## 1. Imports and helper utilities
#
# The helpers below keep the notebook self-contained: they resolve the repository
# root automatically, standardise datetime conversions, and expose a Pareto-front
# filter for the multi-objective analysis.

# %%
from __future__ import annotations

from pathlib import Path
from typing import List

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8")


def find_repo_root(start: Path | None = None) -> Path:
    start = Path(start or Path.cwd()).resolve()
    for parent in [start, *start.parents]:
        if (parent / ".git").exists():
            return parent
    raise RuntimeError("Could not locate repository root from" f" {start}")


def safe_to_datetime(series: pd.Series) -> pd.Series:
    # Convert string timestamps to timezone-aware pandas datetimes. Placeholder
    # values such as 0001-01-01 are mapped to NaT so downstream metrics can drop them.
    cleaned = series.replace({"": pd.NA, "0001-01-01T00:00:00Z": pd.NA})
    return pd.to_datetime(cleaned, utc=True, errors="coerce")


def compute_wait_seconds(submit: pd.Series, start: pd.Series) -> pd.Series:
    wait = (start - submit).dt.total_seconds()
    return wait


def compute_runtime_seconds(start: pd.Series, end: pd.Series) -> pd.Series:
    runtime = (end - start).dt.total_seconds()
    return runtime


def pareto_front(points: np.ndarray) -> np.ndarray:
    # Return a boolean mask for the Pareto-efficient points (minimisation).
    if points.ndim != 2:
        raise ValueError("Pareto front expects a 2D array")
    n_points = points.shape[0]
    is_efficient = np.ones(n_points, dtype=bool)
    for i in range(n_points):
        if not is_efficient[i]:
            continue
        dominated = np.all(points >= points[i], axis=1) & np.any(points > points[i], axis=1)
        is_efficient &= ~dominated
    return is_efficient


repo_root = find_repo_root()
figures_dir = repo_root / "analysis" / "figures"
figures_dir.mkdir(parents=True, exist_ok=True)

repo_root, figures_dir
# Out:
# (PosixPath('/home/goncalo/KubeEnergyScheduler'),
#  PosixPath('/home/goncalo/KubeEnergyScheduler/analysis/figures'))

# %% [markdown]
# ## 2. Locate experiment artefacts
#
# Both the simulator and the Kubernetes replay export CSV/JSON artefacts. Update the
# paths below if you want to compare different runs.

# %%
# Simulator artefacts (per-job traces  summary metrics)
sim_dir = repo_root / "kubenergysched" / "results_latest"
sim_summary_path = sim_dir / "summary.csv"

# Kubernetes replay decisions (JSONL  optional CSV projection)
k8_decisions_jsonl = repo_root / "decisions.jsonl"
k8_decisions_csv = repo_root / "decisions.csv"

sim_dir, sim_summary_path, k8_decisions_jsonl, k8_decisions_csv
# Out:
# (PosixPath('/home/goncalo/KubeEnergyScheduler/kubenergysched/results_latest'),
#  PosixPath('/home/goncalo/KubeEnergyScheduler/kubenergysched/results_latest/summary.csv'),
#  PosixPath('/home/goncalo/KubeEnergyScheduler/decisions.jsonl'),
#  PosixPath('/home/goncalo/KubeEnergyScheduler/decisions.csv'))

# %% [markdown]
# ## 3. Load simulator traces
#
# The simulator stores one CSV per scheduler/policy configuration with per-job
# records. We consolidate them into a single `DataFrame` and derive the wait/runtime
# features required for the comparisons. The aggregated metrics are loaded from the
# `summary.csv` file emitted at the end of the simulation batch.

# %%
sim_per_job_frames: List[pd.DataFrame] = []

for csv_path in sorted(sim_dir.glob("*_results.csv")):
    if csv_path.name == "summary.csv":
        continue
    df = pd.read_csv(csv_path)
    # Ensure the common schema
    df["submit"] = pd.to_datetime(df["submit"], utc=True, errors="coerce")
    df["start"] = pd.to_datetime(df["start"], utc=True, errors="coerce")
    df["end"] = pd.to_datetime(df["end"], utc=True, errors="coerce")
    df["wait_s"] = df["wait_ms"].astype(float) / 1000.0
    df["runtime_s"] = compute_runtime_seconds(df["start"], df["end"])
    df["source"] = "simulator"

    # Add identifiers extracted from the filename (policy  configuration)
    base_name, ci_weight, batch_size, _ = csv_path.stem.rsplit("_", 3)
    df["policy"] = base_name
    df["ci_weight"] = float(ci_weight)
    df["batch_size"] = int(batch_size)
    sim_per_job_frames.append(df)

sim_per_job = pd.concat(sim_per_job_frames, ignore_index=True)
sim_per_job.head()
# Out:
#           sched   job_id    site      node                    submit  \
# 0  carbonscaler  job-000  site-b  site-b-2 2025-01-01 00:00:00+00:00
# 1  carbonscaler  job-001  site-b  site-b-2 2025-01-01 00:03:00+00:00
# 2  carbonscaler  job-002  site-b  site-b-1 2025-01-01 00:06:00+00:00
# 3  carbonscaler  job-003  site-a  site-a-1 2025-01-01 00:09:00+00:00
# 4  carbonscaler  job-004  site-a  site-a-2 2025-01-01 00:12:00+00:00
#
#                       start                       end  wait_ms   ci_cost  \
# 0 2025-01-01 00:00:00+00:00 2025-01-01 00:30:00+00:00        0  0.014674
# 1 2025-01-01 00:30:00+00:00 2025-01-01 01:00:00+00:00  1620000  0.014674
# 2 2025-01-01 00:30:00+00:00 2025-01-01 00:55:00+00:00  1440000  0.014943
# 3 2025-01-01 00:45:00+00:00 2025-01-01 01:20:00+00:00  2160000  0.134012
# 4 2025-01-01 00:30:00+00:00 2025-01-01 00:50:00+00:00  1080000  0.085249
#
#    wait_s  runtime_s     source        policy  ci_weight  batch_size
# 0     0.0     1800.0  simulator  carbonscaler        0.2        1000
# 1  1620.0     1800.0  simulator  carbonscaler        0.2        1000
# 2  1440.0     1500.0  simulator  carbonscaler        0.2        1000
# 3  2160.0     2100.0  simulator  carbonscaler        0.2        1000
# 4  1080.0     1200.0  simulator  carbonscaler        0.2        1000

# %%
sim_summary = pd.read_csv(sim_summary_path)
sim_summary["source"] = "simulator"
sim_summary
# Out:
#           policy  ci_weight  batch_size  total_ci_cost_g  avg_ci_per_job_g  \
# 0            k8s        0.2        1000         3.350728          0.069807
# 1          keids        0.2        1000         3.046470          0.063468
# 2         topsis        0.2        1000         3.007783          0.062662
# 3   carbonscaler        0.2        1000         3.058314          0.063715
# 4      hetpolicy        0.2        1000         2.854988          0.059479
# 5            k8s        0.2         200         3.350728          0.069807
# 6          keids        0.2         200         3.046470          0.063468
# 7         topsis        0.2         200         3.007783          0.062662
# 8   carbonscaler        0.2         200         3.058314          0.063715
# 9      hetpolicy        0.2         200         2.854988          0.059479
# 10           k8s        0.2         500         3.350728          0.069807
# 11         keids        0.2         500         3.046470          0.063468
# 12        topsis        0.2         500         3.007783          0.062662
# 13  carbonscaler        0.2         500         3.058314          0.063715
# 14     hetpolicy        0.2         500         2.854988          0.059479
# 15           k8s        0.4        1000         3.350728          0.069807
# 16         keids        0.4        1000         3.046470          0.063468
# 17        topsis        0.4        1000         3.007783          0.062662
# 18  carbonscaler        0.4        1000         3.058314          0.063715
# 19     hetpolicy        0.4        1000         2.854988          0.059479
# 20           k8s        0.4         200         3.350728          0.069807
# 21         keids        0.4         200         3.046470          0.063468
# 22        topsis        0.4         200         3.007783          0.062662
# 23  carbonscaler        0.4         200         3.058314          0.063715
# 24     hetpolicy        0.4         200         2.854988          0.059479
# 25           k8s        0.4         500         3.350728          0.069807
# 26         keids        0.4         500         3.046470          0.063468
# 27        topsis        0.4         500         3.007783          0.062662
# 28  carbonscaler        0.4         500         3.058314          0.063715
# 29     hetpolicy        0.4         500         2.854988          0.059479
# 30           k8s        0.6        1000         3.350728          0.069807
# 31         keids        0.6        1000         3.046470          0.063468
# 32        topsis        0.6        1000         3.007783          0.062662
# 33  carbonscaler        0.6        1000         3.046470          0.063468
# 34     hetpolicy        0.6        1000         2.854988          0.059479
# 35           k8s        0.6         200         3.350728          0.069807
# 36         keids        0.6         200         3.046470          0.063468
# 37        topsis        0.6         200         3.007783          0.062662
# 38  carbonscaler        0.6         200         3.046470          0.063468
# 39     hetpolicy        0.6         200         2.854988          0.059479
# 40           k8s        0.6         500         3.350728          0.069807
# 41         keids        0.6         500         3.046470          0.063468
# 42        topsis        0.6         500         3.007783          0.062662
# 43  carbonscaler        0.6         500         3.046470          0.063468
# 44     hetpolicy        0.6         500         2.854988          0.059479
# 45           k8s        0.8        1000         3.350728          0.069807
# 46         keids        0.8        1000         3.046470          0.063468
# 47        topsis        0.8        1000         3.007783          0.062662
# 48  carbonscaler        0.8        1000         3.046470          0.063468
# 49     hetpolicy        0.8        1000         2.854988          0.059479
# 50           k8s        0.8         200         3.350728          0.069807
# 51         keids        0.8         200         3.046470          0.063468
# 52        topsis        0.8         200         3.007783          0.062662
# 53  carbonscaler        0.8         200         3.046470          0.063468
# 54     hetpolicy        0.8         200         2.854988          0.059479
# 55           k8s        0.8         500         3.350728          0.069807
# 56         keids        0.8         500         3.046470          0.063468
# 57        topsis        0.8         500         3.007783          0.062662
# 58  carbonscaler        0.8         500         3.046470          0.063468
# 59     hetpolicy        0.8         500         2.854988          0.059479
#
#     cfp_g_per_cpu_hour  avg_wait_s  makespan_s  elapsed_ms  num_jobs  alpha  \
# 0             0.011462     4320.00     15600.0         1.0        48   0.00
# 1             0.010677     2363.75     14700.0         1.0        48   0.58
# 2             0.010456     2407.50     16200.0         1.0        48   0.58
# 3             0.010693     2413.75     15000.0         1.0        48   0.00
# 4             0.010270     2020.00     14400.0         1.0        48   0.58
# 5             0.011462     4320.00     15600.0         1.0        48   0.00
# 6             0.010677     2363.75     14700.0         1.0        48   0.58
# 7             0.010456     2407.50     16200.0         1.0        48   0.58
# 8             0.010693     2413.75     15000.0         1.0        48   0.00
# 9             0.010270     2020.00     14400.0         1.0        48   0.58
# 10            0.011462     4320.00     15600.0         2.0        48   0.00
# 11            0.010677     2363.75     14700.0         1.0        48   0.58
# 12            0.010456     2407.50     16200.0         1.0        48   0.58
# 13            0.010693     2413.75     15000.0         1.0        48   0.00
# 14            0.010270     2020.00     14400.0         1.0        48   0.58
# 15            0.011462     4320.00     15600.0         1.0        48   0.00
# 16            0.010677     2363.75     14700.0         1.0        48   0.58
# 17            0.010456     2407.50     16200.0         1.0        48   0.58
# 18            0.010693     2413.75     15000.0         1.0        48   0.00
# 19            0.010270     2020.00     14400.0         1.0        48   0.58
# 20            0.011462     4320.00     15600.0         1.0        48   0.00
# 21            0.010677     2363.75     14700.0         1.0        48   0.58
# 22            0.010456     2407.50     16200.0         1.0        48   0.58
# 23            0.010693     2413.75     15000.0         1.0        48   0.00
# 24            0.010270     2020.00     14400.0         1.0        48   0.58
# 25            0.011462     4320.00     15600.0         1.0        48   0.00
# 26            0.010677     2363.75     14700.0         1.0        48   0.58
# 27            0.010456     2407.50     16200.0         1.0        48   0.58
# 28            0.010693     2413.75     15000.0         1.0        48   0.00
# 29            0.010270     2020.00     14400.0         1.0        48   0.58
# 30            0.011462     4320.00     15600.0         1.0        48   0.00
# 31            0.010677     2363.75     14700.0         1.0        48   0.58
# 32            0.010456     2407.50     16200.0         1.0        48   0.58
# 33            0.010677     2363.75     14700.0         1.0        48   0.00
# 34            0.010270     2020.00     14400.0         1.0        48   0.58
# 35            0.011462     4320.00     15600.0         1.0        48   0.00
# 36            0.010677     2363.75     14700.0         1.0        48   0.58
# 37            0.010456     2407.50     16200.0         1.0        48   0.58
# 38            0.010677     2363.75     14700.0         1.0        48   0.00
# 39            0.010270     2020.00     14400.0         1.0        48   0.58
# 40            0.011462     4320.00     15600.0         1.0        48   0.00
# 41            0.010677     2363.75     14700.0         1.0        48   0.58
# 42            0.010456     2407.50     16200.0         1.0        48   0.58
# 43            0.010677     2363.75     14700.0         1.0        48   0.00
# 44            0.010270     2020.00     14400.0         1.0        48   0.58
# 45            0.011462     4320.00     15600.0         1.0        48   0.00
# 46            0.010677     2363.75     14700.0         1.0        48   0.58
# 47            0.010456     2407.50     16200.0         1.0        48   0.58
# 48            0.010677     2363.75     14700.0         1.0        48   0.00
# 49            0.010270     2020.00     14400.0         1.0        48   0.58
# 50            0.011462     4320.00     15600.0         1.0        48   0.00
# 51            0.010677     2363.75     14700.0         1.0        48   0.58
# 52            0.010456     2407.50     16200.0         1.0        48   0.58
# 53            0.010677     2363.75     14700.0         1.0        48   0.00
# 54            0.010270     2020.00     14400.0         1.0        48   0.58
# 55            0.011462     4320.00     15600.0         1.0        48   0.00
# 56            0.010677     2363.75     14700.0         1.0        48   0.58
# 57            0.010456     2407.50     16200.0         1.0        48   0.58
# 58            0.010677     2363.75     14700.0         1.0        48   0.00
# 59            0.010270     2020.00     14400.0         1.0        48   0.58
#
#     beta  gamma  alpha_mass  lookahead_min  duration_scale  \
# 0   0.00   0.00         1.0              0             1.0
# 1   0.21   0.21         1.0              0             1.0
# 2   0.21   0.21         1.0              0             1.0
# 3   0.00   0.00         1.0              0             1.0
# 4   0.21   0.21         1.0              0             1.0
# 5   0.00   0.00         1.0              0             1.0
# 6   0.21   0.21         1.0              0             1.0
# 7   0.21   0.21         1.0              0             1.0
# 8   0.00   0.00         1.0              0             1.0
# 9   0.21   0.21         1.0              0             1.0
# 10  0.00   0.00         1.0              0             1.0
# 11  0.21   0.21         1.0              0             1.0
# 12  0.21   0.21         1.0              0             1.0
# 13  0.00   0.00         1.0              0             1.0
# 14  0.21   0.21         1.0              0             1.0
# 15  0.00   0.00         1.0              0             1.0
# 16  0.21   0.21         1.0              0             1.0
# 17  0.21   0.21         1.0              0             1.0
# 18  0.00   0.00         1.0              0             1.0
# 19  0.21   0.21         1.0              0             1.0
# 20  0.00   0.00         1.0              0             1.0
# 21  0.21   0.21         1.0              0             1.0
# 22  0.21   0.21         1.0              0             1.0
# 23  0.00   0.00         1.0              0             1.0
# 24  0.21   0.21         1.0              0             1.0
# 25  0.00   0.00         1.0              0             1.0
# 26  0.21   0.21         1.0              0             1.0
# 27  0.21   0.21         1.0              0             1.0
# 28  0.00   0.00         1.0              0             1.0
# 29  0.21   0.21         1.0              0             1.0
# 30  0.00   0.00         1.0              0             1.0
# 31  0.21   0.21         1.0              0             1.0
# 32  0.21   0.21         1.0              0             1.0
# 33  0.00   0.00         1.0              0             1.0
# 34  0.21   0.21         1.0              0             1.0
# 35  0.00   0.00         1.0              0             1.0
# 36  0.21   0.21         1.0              0             1.0
# 37  0.21   0.21         1.0              0             1.0
# 38  0.00   0.00         1.0              0             1.0
# 39  0.21   0.21         1.0              0             1.0
# 40  0.00   0.00         1.0              0             1.0
# 41  0.21   0.21         1.0              0             1.0
# 42  0.21   0.21         1.0              0             1.0
# 43  0.00   0.00         1.0              0             1.0
# 44  0.21   0.21         1.0              0             1.0
# 45  0.00   0.00         1.0              0             1.0
# 46  0.21   0.21         1.0              0             1.0
# 47  0.21   0.21         1.0              0             1.0
# 48  0.00   0.00         1.0              0             1.0
# 49  0.21   0.21         1.0              0             1.0
# 50  0.00   0.00         1.0              0             1.0
# 51  0.21   0.21         1.0              0             1.0
# 52  0.21   0.21         1.0              0             1.0
# 53  0.00   0.00         1.0              0             1.0
# 54  0.21   0.21         1.0              0             1.0
# 55  0.00   0.00         1.0              0             1.0
# 56  0.21   0.21         1.0              0             1.0
# 57  0.21   0.21         1.0              0             1.0
# 58  0.00   0.00         1.0              0             1.0
# 59  0.21   0.21         1.0              0             1.0
#
#     duration_overrides     source
# 0                  NaN  simulator
# 1                  NaN  simulator
# 2                  NaN  simulator
# 3                  NaN  simulator
# 4                  NaN  simulator
# 5                  NaN  simulator
# 6                  NaN  simulator
# 7                  NaN  simulator
# 8                  NaN  simulator
# 9                  NaN  simulator
# 10                 NaN  simulator
# 11                 NaN  simulator
# 12                 NaN  simulator
# 13                 NaN  simulator
# 14                 NaN  simulator
# 15                 NaN  simulator
# 16                 NaN  simulator
# 17                 NaN  simulator
# 18                 NaN  simulator
# 19                 NaN  simulator
# 20                 NaN  simulator
# 21                 NaN  simulator
# 22                 NaN  simulator
# 23                 NaN  simulator
# 24                 NaN  simulator
# 25                 NaN  simulator
# 26                 NaN  simulator
# 27                 NaN  simulator
# 28                 NaN  simulator
# 29                 NaN  simulator
# 30                 NaN  simulator
# 31                 NaN  simulator
# 32                 NaN  simulator
# 33                 NaN  simulator
# 34                 NaN  simulator
# 35                 NaN  simulator
# 36                 NaN  simulator
# 37                 NaN  simulator
# 38                 NaN  simulator
# 39                 NaN  simulator
# 40                 NaN  simulator
# 41                 NaN  simulator
# 42                 NaN  simulator
# 43                 NaN  simulator
# 44                 NaN  simulator
# 45                 NaN  simulator
# 46                 NaN  simulator
# 47                 NaN  simulator
# 48                 NaN  simulator
# 49                 NaN  simulator
# 50                 NaN  simulator
# 51                 NaN  simulator
# 52                 NaN  simulator
# 53                 NaN  simulator
# 54                 NaN  simulator
# 55                 NaN  simulator
# 56                 NaN  simulator
# 57                 NaN  simulator
# 58                 NaN  simulator
# 59                 NaN  simulator

# %% [markdown]
# ## 4. Load Kubernetes replay decisions
#
# The controller exports one JSONL record per scheduling decision. The snippet below
# filters Kubernetes-native results (`result_type == "kub_result"`), converts the
# timestamps, and derives wait/runtime metrics to mirror the simulator schema.

# %%
k8_decisions = pd.read_json(k8_decisions_jsonl, lines=True)
k8_decisions = k8_decisions.query("result_type == 'kub_result'").copy()

k8_decisions["submit"] = safe_to_datetime(k8_decisions["queued_at"])
k8_decisions["start"] = safe_to_datetime(k8_decisions["started_at"])
k8_decisions["end"] = safe_to_datetime(k8_decisions["ended_at"])

k8_decisions["wait_s"] = compute_wait_seconds(k8_decisions["submit"], k8_decisions["start"])
k8_decisions["runtime_s"] = compute_runtime_seconds(k8_decisions["start"], k8_decisions["end"])

# The replay uses a single scheduler labelled "engine" in this trace.
k8_decisions["policy"] = k8_decisions["scheduler"]
k8_decisions["source"] = "kubernetes"

k8_decisions[[
    "result_id", "scheduler", "job_id", "site", "node", "wait_s", "runtime_s", "fallback", "cost"
]].head()
# Out:
# Empty DataFrame
# Columns: [result_id, scheduler, job_id, site, node, wait_s, runtime_s, fallback, cost]
# Index: []

# %% [markdown]
# ## 5. Harmonise schemas
#
# To compare the two environments we keep only the shared columns and annotate the
# origin. The helper below produces a tidy table that concatenates simulator and
# Kubernetes traces.

# %%
common_cols = [
    "policy", "job_id", "site", "node", "submit", "start", "end",
    "wait_s", "runtime_s", "ci_cost", "source"
]

sim_view = sim_per_job.copy()
if "policy" not in sim_view.columns:
    sim_view["policy"] = sim_view["sched"]
if "sched" in sim_view.columns:
    sim_view = sim_view.drop(columns=["sched"])
for col in ["site", "node"]:
    if col not in sim_view:
        sim_view[col] = pd.NA
sim_view["ci_cost"] = sim_view["ci_cost"].astype(float)

k8_view = k8_decisions.copy()
if "ci_cost" not in k8_view.columns:
    k8_view["ci_cost"] = k8_view.get("cost", 0.0)

combined = pd.concat(
    [sim_view[common_cols], k8_view[common_cols]],
    ignore_index=True,
    sort=False,
)
combined.head()
# Out:
#          policy   job_id    site      node                    submit  \
# 0  carbonscaler  job-000  site-b  site-b-2 2025-01-01 00:00:00+00:00
# 1  carbonscaler  job-001  site-b  site-b-2 2025-01-01 00:03:00+00:00
# 2  carbonscaler  job-002  site-b  site-b-1 2025-01-01 00:06:00+00:00
# 3  carbonscaler  job-003  site-a  site-a-1 2025-01-01 00:09:00+00:00
# 4  carbonscaler  job-004  site-a  site-a-2 2025-01-01 00:12:00+00:00
#
#                       start                       end  wait_s  runtime_s  \
# 0 2025-01-01 00:00:00+00:00 2025-01-01 00:30:00+00:00     0.0     1800.0
# 1 2025-01-01 00:30:00+00:00 2025-01-01 01:00:00+00:00  1620.0     1800.0
# 2 2025-01-01 00:30:00+00:00 2025-01-01 00:55:00+00:00  1440.0     1500.0
# 3 2025-01-01 00:45:00+00:00 2025-01-01 01:20:00+00:00  2160.0     2100.0
# 4 2025-01-01 00:30:00+00:00 2025-01-01 00:50:00+00:00  1080.0     1200.0
#
#     ci_cost     source
# 0  0.014674  simulator
# 1  0.014674  simulator
# 2  0.014943  simulator
# 3  0.134012  simulator
# 4  0.085249  simulator

# %% [markdown]
# ### Policy-specific Pareto fronts
#
# To understand how each KesPolicies strategy behaves across the CI weight/batch sweep, we compute a Pareto set per policy (minimising total carbon vs. average wait). The plots below highlight non-dominated configurations, and the consolidated table summarises the associated parameters.

# %%
policy_pareto_frames: list[pd.DataFrame] = []
policy_pareto_fig_records: list[dict[str, str]] = []

for policy, group in sim_summary.groupby('policy', sort=True):
    if group.empty:
        continue
    metrics = group[['total_ci_cost_g', 'avg_wait_s']].to_numpy()
    mask = pareto_front(metrics)
    front = (
        group.loc[mask, ['policy', 'ci_weight', 'batch_size', 'total_ci_cost_g', 'avg_wait_s']]
        .sort_values(['total_ci_cost_g', 'avg_wait_s'])
        .reset_index(drop=True)
    )
    policy_pareto_frames.append(front)

    fig, ax = plt.subplots(figsize=(7.5, 5))
    ax.scatter(
        group['total_ci_cost_g'],
        group['avg_wait_s'],
        color='lightgray',
        label='All configurations',
    )
    ax.scatter(
        front['total_ci_cost_g'],
        front['avg_wait_s'],
        color='tab:green',
        label='Pareto front',
    )
    if len(front) > 1:
        ax.plot(
            front['total_ci_cost_g'],
            front['avg_wait_s'],
            color='tab:green',
            linestyle='--',
            linewidth=1,
        )
    for _, row in front.iterrows():
        ax.annotate(
            f"w={row['ci_weight']:.1f}, b={row['batch_size']}",
            (row['total_ci_cost_g'], row['avg_wait_s']),
            textcoords='offset points',
            xytext=(4, 6),
        )
    ax.set_xlabel('Total CI cost (g)')
    ax.set_ylabel('Average wait (s)')
    ax.set_title(f'{policy}: carbon vs. wait Pareto front')
    ax.legend()
    fig.tight_layout()

    fig_path = figures_dir / f"{policy}_pareto_front.png"
    fig.savefig(fig_path, dpi=300)
    plt.close(fig)

    policy_pareto_fig_records.append({'policy': policy, 'figure_path': str(fig_path)})

if policy_pareto_frames:
    per_policy_pareto_table = (
        pd.concat(policy_pareto_frames, ignore_index=True)
        .sort_values(['policy', 'total_ci_cost_g', 'avg_wait_s'])
    )
    policy_pareto_figures = pd.DataFrame(policy_pareto_fig_records)
else:
    per_policy_pareto_table = pd.DataFrame()
    policy_pareto_figures = pd.DataFrame(columns=['policy', 'figure_path'])

policy_pareto_figures, per_policy_pareto_table
# Out:
# (         policy                                        figure_path
#  0  carbonscaler  /home/goncalo/KubeEnergyScheduler/analysis/fig...
#  1     hetpolicy  /home/goncalo/KubeEnergyScheduler/analysis/fig...
#  2           k8s  /home/goncalo/KubeEnergyScheduler/analysis/fig...
#  3         keids  /home/goncalo/KubeEnergyScheduler/analysis/fig...
#  4        topsis  /home/goncalo/KubeEnergyScheduler/analysis/fig...,
#            policy  ci_weight  batch_size  total_ci_cost_g  avg_wait_s
#  0   carbonscaler        0.6        1000         3.046470     2363.75
#  1   carbonscaler        0.6         200         3.046470     2363.75
#  2   carbonscaler        0.6         500         3.046470     2363.75
#  3   carbonscaler        0.8        1000         3.046470     2363.75
#  4   carbonscaler        0.8         200         3.046470     2363.75
#  5   carbonscaler        0.8         500         3.046470     2363.75
#  6      hetpolicy        0.2        1000         2.854988     2020.00
#  7      hetpolicy        0.2         200         2.854988     2020.00
#  8      hetpolicy        0.2         500         2.854988     2020.00
#  9      hetpolicy        0.4        1000         2.854988     2020.00
#  10     hetpolicy        0.4         200         2.854988     2020.00
#  11     hetpolicy        0.4         500         2.854988     2020.00
#  12     hetpolicy        0.6        1000         2.854988     2020.00
#  13     hetpolicy        0.6         200         2.854988     2020.00
#  14     hetpolicy        0.6         500         2.854988     2020.00
#  15     hetpolicy        0.8        1000         2.854988     2020.00
#  16     hetpolicy        0.8         200         2.854988     2020.00
#  17     hetpolicy        0.8         500         2.854988     2020.00
#  18           k8s        0.2        1000         3.350728     4320.00
#  19           k8s        0.2         200         3.350728     4320.00
#  20           k8s        0.2         500         3.350728     4320.00
#  21           k8s        0.4        1000         3.350728     4320.00
#  22           k8s        0.4         200         3.350728     4320.00
#  23           k8s        0.4         500         3.350728     4320.00
#  24           k8s        0.6        1000         3.350728     4320.00
#  25           k8s        0.6         200         3.350728     4320.00
#  26           k8s        0.6         500         3.350728     4320.00
#  27           k8s        0.8        1000         3.350728     4320.00
#  28           k8s        0.8         200         3.350728     4320.00
#  29           k8s        0.8         500         3.350728     4320.00
#  30         keids        0.2        1000         3.046470     2363.75
#  31         keids        0.2         200         3.046470     2363.75
#  32         keids        0.2         500         3.046470     2363.75
#  33         keids        0.4        1000         3.046470     2363.75
#  34         keids        0.4         200         3.046470     2363.75
#  35         keids        0.4         500         3.046470     2363.75
#  36         keids        0.6        1000         3.046470     2363.75
#  37         keids        0.6         200         3.046470     2363.75
#  38         keids        0.6         500         3.046470     2363.75
#  39         keids        0.8        1000         3.046470     2363.75
#  40         keids        0.8         200         3.046470     2363.75
#  41         keids        0.8         500         3.046470     2363.75
#  42        topsis        0.2        1000         3.007783     2407.50
#  43        topsis        0.2         200         3.007783     2407.50
#  44        topsis        0.2         500         3.007783     2407.50
#  45        topsis        0.4        1000         3.007783     2407.50
#  46        topsis        0.4         200         3.007783     2407.50
#  47        topsis        0.4         500         3.007783     2407.50
#  48        topsis        0.6        1000         3.007783     2407.50
#  49        topsis        0.6         200         3.007783     2407.50
#  50        topsis        0.6         500         3.007783     2407.50
#  51        topsis        0.8        1000         3.007783     2407.50
#  52        topsis        0.8         200         3.007783     2407.50
#  53        topsis        0.8         500         3.007783     2407.50)

# %% [markdown]
# ## 6. Summary metrics per environment
#
# The next cells compute aggregate indicators (number of jobs, completion ratio,
# carbon impact, wait time, fallback rate) to sanity-check the two datasets before
# digging into the Pareto analysis.

# %%
def summarise_jobs(df: pd.DataFrame) -> pd.Series:
    completed = df["end"].notna()
    submit = df["submit"].dropna()
    end_times = df.loc[completed, "end"]

    makespan = (end_times.max() - submit.min()).total_seconds() if not end_times.empty and not submit.empty else np.nan

    return pd.Series({
        "jobs": len(df),
        "completed_jobs": int(completed.sum()),
        "completion_ratio": completed.mean() if len(df) else np.nan,
        "fallback_ratio": df.get("fallback", pd.Series(dtype=float)).mean() if "fallback" in df else np.nan,
        "total_ci_cost_g": df["ci_cost"].sum(),
        "avg_ci_per_job_g": df["ci_cost"].mean(),
        "avg_wait_s": df["wait_s"].mean(),
        "avg_runtime_s": df["runtime_s"].mean(),
        "makespan_s": makespan,
    })

summary_by_source = combined.groupby(["source", "policy"]).apply(summarise_jobs).reset_index()
summary_by_source
# Out:
# /tmp/ipykernel_3772711/3002507737.py:20: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   summary_by_source = combined.groupby(["source", "policy"]).apply(summarise_jobs).reset_index()
#       source        policy   jobs  completed_jobs  completion_ratio  \
# 0  simulator  carbonscaler  576.0           576.0               1.0
# 1  simulator     hetpolicy  576.0           576.0               1.0
# 2  simulator           k8s  576.0           576.0               1.0
# 3  simulator         keids  576.0           576.0               1.0
# 4  simulator        topsis  576.0           576.0               1.0
#
#    fallback_ratio  total_ci_cost_g  avg_ci_per_job_g  avg_wait_s  \
# 0             NaN        36.628674          0.063591     2388.75
# 1             NaN        34.259856          0.059479     2020.00
# 2             NaN        40.208724          0.069807     4320.00
# 3             NaN        36.557616          0.063468     2363.75
# 4             NaN        36.093396          0.062662     2407.50
#
#    avg_runtime_s  makespan_s
# 0         1525.0     15000.0
# 1         1487.5     14400.0
# 2         1575.0     16500.0
# 3         1525.0     14700.0
# 4         1537.5     16200.0

# %% [markdown]
# The simulator additionally exposes rich metadata (configuration weights, elapsed
# simulation time) via `summary.csv`. Joining that file with the per-job aggregates
# helps confirm consistency and provides the inputs for the Pareto plot.

# %%
sim_summary_metrics = summary_by_source.query("source == 'simulator'").merge(
    sim_summary,
    on=["policy"],
    how="left",
    suffixes=("_jobs", "_reported"),
)
sim_summary_metrics[[
    "policy",
    "jobs",
    "total_ci_cost_g_jobs",
    "total_ci_cost_g_reported",
    "avg_wait_s_jobs",
    "avg_wait_s_reported",
]]
# Out:
#           policy   jobs  total_ci_cost_g_jobs  total_ci_cost_g_reported  \
# 0   carbonscaler  576.0             36.628674                  3.058314
# 1   carbonscaler  576.0             36.628674                  3.058314
# 2   carbonscaler  576.0             36.628674                  3.058314
# 3   carbonscaler  576.0             36.628674                  3.058314
# 4   carbonscaler  576.0             36.628674                  3.058314
# 5   carbonscaler  576.0             36.628674                  3.058314
# 6   carbonscaler  576.0             36.628674                  3.046470
# 7   carbonscaler  576.0             36.628674                  3.046470
# 8   carbonscaler  576.0             36.628674                  3.046470
# 9   carbonscaler  576.0             36.628674                  3.046470
# 10  carbonscaler  576.0             36.628674                  3.046470
# 11  carbonscaler  576.0             36.628674                  3.046470
# 12     hetpolicy  576.0             34.259856                  2.854988
# 13     hetpolicy  576.0             34.259856                  2.854988
# 14     hetpolicy  576.0             34.259856                  2.854988
# 15     hetpolicy  576.0             34.259856                  2.854988
# 16     hetpolicy  576.0             34.259856                  2.854988
# 17     hetpolicy  576.0             34.259856                  2.854988
# 18     hetpolicy  576.0             34.259856                  2.854988
# 19     hetpolicy  576.0             34.259856                  2.854988
# 20     hetpolicy  576.0             34.259856                  2.854988
# 21     hetpolicy  576.0             34.259856                  2.854988
# 22     hetpolicy  576.0             34.259856                  2.854988
# 23     hetpolicy  576.0             34.259856                  2.854988
# 24           k8s  576.0             40.208724                  3.350728
# 25           k8s  576.0             40.208724                  3.350728
# 26           k8s  576.0             40.208724                  3.350728
# 27           k8s  576.0             40.208724                  3.350728
# 28           k8s  576.0             40.208724                  3.350728
# 29           k8s  576.0             40.208724                  3.350728
# 30           k8s  576.0             40.208724                  3.350728
# 31           k8s  576.0             40.208724                  3.350728
# 32           k8s  576.0             40.208724                  3.350728
# 33           k8s  576.0             40.208724                  3.350728
# 34           k8s  576.0             40.208724                  3.350728
# 35           k8s  576.0             40.208724                  3.350728
# 36         keids  576.0             36.557616                  3.046470
# 37         keids  576.0             36.557616                  3.046470
# 38         keids  576.0             36.557616                  3.046470
# 39         keids  576.0             36.557616                  3.046470
# 40         keids  576.0             36.557616                  3.046470
# 41         keids  576.0             36.557616                  3.046470
# 42         keids  576.0             36.557616                  3.046470
# 43         keids  576.0             36.557616                  3.046470
# 44         keids  576.0             36.557616                  3.046470
# 45         keids  576.0             36.557616                  3.046470
# 46         keids  576.0             36.557616                  3.046470
# 47         keids  576.0             36.557616                  3.046470
# 48        topsis  576.0             36.093396                  3.007783
# 49        topsis  576.0             36.093396                  3.007783
# 50        topsis  576.0             36.093396                  3.007783
# 51        topsis  576.0             36.093396                  3.007783
# 52        topsis  576.0             36.093396                  3.007783
# 53        topsis  576.0             36.093396                  3.007783
# 54        topsis  576.0             36.093396                  3.007783
# 55        topsis  576.0             36.093396                  3.007783
# 56        topsis  576.0             36.093396                  3.007783
# 57        topsis  576.0             36.093396                  3.007783
# 58        topsis  576.0             36.093396                  3.007783
# 59        topsis  576.0             36.093396                  3.007783
#
#     avg_wait_s_jobs  avg_wait_s_reported
# 0           2388.75              2413.75
# 1           2388.75              2413.75
# 2           2388.75              2413.75
# 3           2388.75              2413.75
# 4           2388.75              2413.75
# 5           2388.75              2413.75
# 6           2388.75              2363.75
# 7           2388.75              2363.75
# 8           2388.75              2363.75
# 9           2388.75              2363.75
# 10          2388.75              2363.75
# 11          2388.75              2363.75
# 12          2020.00              2020.00
# 13          2020.00              2020.00
# 14          2020.00              2020.00
# 15          2020.00              2020.00
# 16          2020.00              2020.00
# 17          2020.00              2020.00
# 18          2020.00              2020.00
# 19          2020.00              2020.00
# 20          2020.00              2020.00
# 21          2020.00              2020.00
# 22          2020.00              2020.00
# 23          2020.00              2020.00
# 24          4320.00              4320.00
# 25          4320.00              4320.00
# 26          4320.00              4320.00
# 27          4320.00              4320.00
# 28          4320.00              4320.00
# 29          4320.00              4320.00
# 30          4320.00              4320.00
# 31          4320.00              4320.00
# 32          4320.00              4320.00
# 33          4320.00              4320.00
# 34          4320.00              4320.00
# 35          4320.00              4320.00
# 36          2363.75              2363.75
# 37          2363.75              2363.75
# 38          2363.75              2363.75
# 39          2363.75              2363.75
# 40          2363.75              2363.75
# 41          2363.75              2363.75
# 42          2363.75              2363.75
# 43          2363.75              2363.75
# 44          2363.75              2363.75
# 45          2363.75              2363.75
# 46          2363.75              2363.75
# 47          2363.75              2363.75
# 48          2407.50              2407.50
# 49          2407.50              2407.50
# 50          2407.50              2407.50
# 51          2407.50              2407.50
# 52          2407.50              2407.50
# 53          2407.50              2407.50
# 54          2407.50              2407.50
# 55          2407.50              2407.50
# 56          2407.50              2407.50
# 57          2407.50              2407.50
# 58          2407.50              2407.50
# 59          2407.50              2407.50

# %% [markdown]
# ## 6. Evaluation metrics
#
# We materialise the thesis metrics for carbon- and time-aware evaluation. The code below
# implements the definitions from Section 6.2.2: CFP (6.2), SCI (6.3), makespan (6.4),
# latency (6.5), scheduler overhead and throughput (6.6), and the average energy per job.
# All quantities are normalised per batch/policy so that simulator and Kubernetes traces
# can be compared directly once telemetry is populated.

# %%
# Evaluate thesis metrics (CFP, SCI, makespan, latency, scheduler overhead, throughput, energy/job).
nodes_catalog = pd.read_csv(repo_root / "kubenergysched" / "config" / "nodes.csv")
sites_catalog = pd.read_csv(repo_root / "kubenergysched" / "config" / "sites.csv")

node_power_lookup = {}
node_site_lookup = {}
if {"name", "peak_power_w", "site"}.issubset(nodes_catalog.columns):
    node_power_lookup = nodes_catalog.set_index("name")["peak_power_w"].astype(float).to_dict()
    node_site_lookup = nodes_catalog.set_index("name")["site"].to_dict()

site_pue_lookup = {}
if {"id", "pue"}.issubset(sites_catalog.columns):
    site_pue_lookup = sites_catalog.set_index("id")["pue"].astype(float).to_dict()


def compute_evaluation_metrics(frame: pd.DataFrame, fallback_overhead_s: float | None = None) -> pd.Series:
    data = frame.copy()
    if data.empty:
        return pd.Series({
            "jobs_total": 0,
            "jobs_completed": 0,
            "carbon_footprint_g": np.nan,
            "carbon_footprint_kg": np.nan,
            "software_carbon_intensity_g_per_job": np.nan,
            "makespan_s": np.nan,
            "latency_s": np.nan,
            "throughput_jobs_per_hour": np.nan,
            "scheduler_overhead_s": fallback_overhead_s if fallback_overhead_s is not None else np.nan,
            "energy_per_job_wh": np.nan,
        })

    data["submit"] = safe_to_datetime(data["submit"])
    data["start"] = safe_to_datetime(data["start"])
    data["end"] = safe_to_datetime(data["end"])

    if "wait_s" in data.columns:
        data["wait_s"] = data["wait_s"].astype(float)
    else:
        data["wait_s"] = compute_wait_seconds(data["submit"], data["start"])

    if "runtime_s" in data.columns:
        data["runtime_s"] = data["runtime_s"].astype(float)
    else:
        data["runtime_s"] = compute_runtime_seconds(data["start"], data["end"])

    if "ci_cost" in data.columns:
        data["ci_cost"] = data["ci_cost"].astype(float)
    else:
        data["ci_cost"] = 0.0

    completed_mask = data["end"].notna()
    jobs_total = int(len(data))
    jobs_completed = int(completed_mask.sum())

    cfp_total_g = float(data.loc[completed_mask, "ci_cost"].sum())
    sci_g_per_job = cfp_total_g / jobs_completed if jobs_completed else np.nan

    arrival_times = data["submit"].dropna()
    completion_times = data.loc[completed_mask, "end"].dropna()
    if not arrival_times.empty and not completion_times.empty:
        makespan_s = (completion_times.max() - arrival_times.min()).total_seconds()
    else:
        makespan_s = np.nan

    latency_s = float(data["wait_s"].mean()) if len(data["wait_s"]) else np.nan

    if jobs_completed and pd.notna(makespan_s) and makespan_s > 0:
        throughput_jobs_per_hour = jobs_completed / (makespan_s / 3600.0)
    else:
        throughput_jobs_per_hour = np.nan

    energy_series = None
    for candidate in ("energy_wh", "job_energy_wh"):
        if candidate in data.columns:
            energy_series = data.loc[completed_mask, candidate].astype(float)
            break

    if energy_series is None:
        estimates = []
        for idx, row in data.loc[completed_mask].iterrows():
            node = row.get("node")
            runtime_s = row.get("runtime_s")
            power_w = node_power_lookup.get(node)
            if power_w is None or pd.isna(runtime_s) or runtime_s <= 0:
                estimates.append(np.nan)
                continue
            site_id = node_site_lookup.get(node)
            pue = site_pue_lookup.get(site_id, 1.0)
            estimates.append(power_w * pue * (runtime_s / 3600.0))
        if estimates:
            energy_series = pd.Series(estimates, index=data.loc[completed_mask].index, dtype=float)

    if energy_series is not None and energy_series.notna().any():
        total_energy_wh = float(energy_series.dropna().sum())
        energy_per_job_wh = total_energy_wh / jobs_completed if jobs_completed else np.nan
    else:
        energy_per_job_wh = np.nan

    if "scheduler_latency_s" in data.columns:
        scheduler_overhead_s = float(data["scheduler_latency_s"].astype(float).mean())
    elif "scheduler_latency_ms" in data.columns:
        scheduler_overhead_s = float(data["scheduler_latency_ms"].astype(float).mean() / 1000.0)
    elif fallback_overhead_s is not None:
        scheduler_overhead_s = float(fallback_overhead_s)
    else:
        scheduler_overhead_s = np.nan

    return pd.Series({
        "jobs_total": jobs_total,
        "jobs_completed": jobs_completed,
        "carbon_footprint_g": cfp_total_g,
        "carbon_footprint_kg": cfp_total_g / 1000.0 if pd.notna(cfp_total_g) else np.nan,
        "software_carbon_intensity_g_per_job": sci_g_per_job,
        "makespan_s": makespan_s,
        "latency_s": latency_s,
        "throughput_jobs_per_hour": throughput_jobs_per_hour,
        "scheduler_overhead_s": scheduler_overhead_s,
        "energy_per_job_wh": energy_per_job_wh,
    })


sim_overhead_lookup = {}
if not sim_summary.empty:
    temp = sim_summary.copy()
    temp["scheduler_overhead_s"] = (
        temp["elapsed_ms"].astype(float)
        / temp["num_jobs"].astype(float).clip(lower=1.0)
        / 1000.0
    )
    sim_overhead_lookup = temp.set_index(["policy", "ci_weight", "batch_size"])["scheduler_overhead_s"].to_dict()

metrics_rows = []
for (policy, ci_weight, batch_size), group in sim_per_job.groupby(["policy", "ci_weight", "batch_size"], dropna=False):
    fallback = sim_overhead_lookup.get((policy, ci_weight, batch_size))
    metrics = compute_evaluation_metrics(group, fallback_overhead_s=fallback)
    record = metrics.to_dict()
    record.update({
        "source": "simulator",
        "policy": policy,
        "ci_weight": ci_weight,
        "batch_size": batch_size,
    })
    metrics_rows.append(record)

if not k8_decisions.empty:
    if "ci_weight" not in k8_decisions.columns and "theta_c" in k8_decisions.columns:
        k8_decisions = k8_decisions.copy()
        k8_decisions["ci_weight"] = k8_decisions["theta_c"].astype(float)
    for (policy, ci_weight), group in k8_decisions.groupby(["policy", "ci_weight"], dropna=False):
        metrics = compute_evaluation_metrics(group)
        record = metrics.to_dict()
        record.update({
            "source": "kubernetes",
            "policy": policy,
            "ci_weight": ci_weight,
            "batch_size": group.get("batch_size", pd.Series([pd.NA])).iloc[0] if "batch_size" in group else pd.NA,
        })
        metrics_rows.append(record)

evaluation_metrics = pd.DataFrame(metrics_rows)

if not evaluation_metrics.empty:
    ordered_columns = [
        "source",
        "policy",
        "ci_weight",
        "batch_size",
        "jobs_total",
        "jobs_completed",
        "carbon_footprint_g",
        "carbon_footprint_kg",
        "software_carbon_intensity_g_per_job",
        "makespan_s",
        "latency_s",
        "throughput_jobs_per_hour",
        "scheduler_overhead_s",
        "energy_per_job_wh",
    ]
    evaluation_metrics = evaluation_metrics[ordered_columns].sort_values([
        "source",
        "policy",
        "ci_weight",
        "batch_size",
    ])

evaluation_metrics
# Out:
#        source        policy  ci_weight  batch_size  jobs_total  \
# 0   simulator  carbonscaler        0.2         200        48.0
# 1   simulator  carbonscaler        0.2         500        48.0
# 2   simulator  carbonscaler        0.2        1000        48.0
# 3   simulator  carbonscaler        0.4         200        48.0
# 4   simulator  carbonscaler        0.4         500        48.0
# 5   simulator  carbonscaler        0.4        1000        48.0
# 6   simulator  carbonscaler        0.6         200        48.0
# 7   simulator  carbonscaler        0.6         500        48.0
# 8   simulator  carbonscaler        0.6        1000        48.0
# 9   simulator  carbonscaler        0.8         200        48.0
# 10  simulator  carbonscaler        0.8         500        48.0
# 11  simulator  carbonscaler        0.8        1000        48.0
# 12  simulator     hetpolicy        0.2         200        48.0
# 13  simulator     hetpolicy        0.2         500        48.0
# 14  simulator     hetpolicy        0.2        1000        48.0
# 15  simulator     hetpolicy        0.4         200        48.0
# 16  simulator     hetpolicy        0.4         500        48.0
# 17  simulator     hetpolicy        0.4        1000        48.0
# 18  simulator     hetpolicy        0.6         200        48.0
# 19  simulator     hetpolicy        0.6         500        48.0
# 20  simulator     hetpolicy        0.6        1000        48.0
# 21  simulator     hetpolicy        0.8         200        48.0
# 22  simulator     hetpolicy        0.8         500        48.0
# 23  simulator     hetpolicy        0.8        1000        48.0
# 24  simulator           k8s        0.2         200        48.0
# 25  simulator           k8s        0.2         500        48.0
# 26  simulator           k8s        0.2        1000        48.0
# 27  simulator           k8s        0.4         200        48.0
# 28  simulator           k8s        0.4         500        48.0
# 29  simulator           k8s        0.4        1000        48.0
# 30  simulator           k8s        0.6         200        48.0
# 31  simulator           k8s        0.6         500        48.0
# 32  simulator           k8s        0.6        1000        48.0
# 33  simulator           k8s        0.8         200        48.0
# 34  simulator           k8s        0.8         500        48.0
# 35  simulator           k8s        0.8        1000        48.0
# 36  simulator         keids        0.2         200        48.0
# 37  simulator         keids        0.2         500        48.0
# 38  simulator         keids        0.2        1000        48.0
# 39  simulator         keids        0.4         200        48.0
# 40  simulator         keids        0.4         500        48.0
# 41  simulator         keids        0.4        1000        48.0
# 42  simulator         keids        0.6         200        48.0
# 43  simulator         keids        0.6         500        48.0
# 44  simulator         keids        0.6        1000        48.0
# 45  simulator         keids        0.8         200        48.0
# 46  simulator         keids        0.8         500        48.0
# 47  simulator         keids        0.8        1000        48.0
# 48  simulator        topsis        0.2         200        48.0
# 49  simulator        topsis        0.2         500        48.0
# 50  simulator        topsis        0.2        1000        48.0
# 51  simulator        topsis        0.4         200        48.0
# 52  simulator        topsis        0.4         500        48.0
# 53  simulator        topsis        0.4        1000        48.0
# 54  simulator        topsis        0.6         200        48.0
# 55  simulator        topsis        0.6         500        48.0
# 56  simulator        topsis        0.6        1000        48.0
# 57  simulator        topsis        0.8         200        48.0
# 58  simulator        topsis        0.8         500        48.0
# 59  simulator        topsis        0.8        1000        48.0
#
#     jobs_completed  carbon_footprint_g  carbon_footprint_kg  \
# 0             48.0            3.058311             0.003058
# 1             48.0            3.058311             0.003058
# 2             48.0            3.058311             0.003058
# 3             48.0            3.058311             0.003058
# 4             48.0            3.058311             0.003058
# 5             48.0            3.058311             0.003058
# 6             48.0            3.046468             0.003046
# 7             48.0            3.046468             0.003046
# 8             48.0            3.046468             0.003046
# 9             48.0            3.046468             0.003046
# 10            48.0            3.046468             0.003046
# 11            48.0            3.046468             0.003046
# 12            48.0            2.854988             0.002855
# 13            48.0            2.854988             0.002855
# 14            48.0            2.854988             0.002855
# 15            48.0            2.854988             0.002855
# 16            48.0            2.854988             0.002855
# 17            48.0            2.854988             0.002855
# 18            48.0            2.854988             0.002855
# 19            48.0            2.854988             0.002855
# 20            48.0            2.854988             0.002855
# 21            48.0            2.854988             0.002855
# 22            48.0            2.854988             0.002855
# 23            48.0            2.854988             0.002855
# 24            48.0            3.350727             0.003351
# 25            48.0            3.350727             0.003351
# 26            48.0            3.350727             0.003351
# 27            48.0            3.350727             0.003351
# 28            48.0            3.350727             0.003351
# 29            48.0            3.350727             0.003351
# 30            48.0            3.350727             0.003351
# 31            48.0            3.350727             0.003351
# 32            48.0            3.350727             0.003351
# 33            48.0            3.350727             0.003351
# 34            48.0            3.350727             0.003351
# 35            48.0            3.350727             0.003351
# 36            48.0            3.046468             0.003046
# 37            48.0            3.046468             0.003046
# 38            48.0            3.046468             0.003046
# 39            48.0            3.046468             0.003046
# 40            48.0            3.046468             0.003046
# 41            48.0            3.046468             0.003046
# 42            48.0            3.046468             0.003046
# 43            48.0            3.046468             0.003046
# 44            48.0            3.046468             0.003046
# 45            48.0            3.046468             0.003046
# 46            48.0            3.046468             0.003046
# 47            48.0            3.046468             0.003046
# 48            48.0            3.007783             0.003008
# 49            48.0            3.007783             0.003008
# 50            48.0            3.007783             0.003008
# 51            48.0            3.007783             0.003008
# 52            48.0            3.007783             0.003008
# 53            48.0            3.007783             0.003008
# 54            48.0            3.007783             0.003008
# 55            48.0            3.007783             0.003008
# 56            48.0            3.007783             0.003008
# 57            48.0            3.007783             0.003008
# 58            48.0            3.007783             0.003008
# 59            48.0            3.007783             0.003008
#
#     software_carbon_intensity_g_per_job  makespan_s  latency_s  \
# 0                              0.063715     15000.0    2413.75
# 1                              0.063715     15000.0    2413.75
# 2                              0.063715     15000.0    2413.75
# 3                              0.063715     15000.0    2413.75
# 4                              0.063715     15000.0    2413.75
# 5                              0.063715     15000.0    2413.75
# 6                              0.063468     14700.0    2363.75
# 7                              0.063468     14700.0    2363.75
# 8                              0.063468     14700.0    2363.75
# 9                              0.063468     14700.0    2363.75
# 10                             0.063468     14700.0    2363.75
# 11                             0.063468     14700.0    2363.75
# 12                             0.059479     14400.0    2020.00
# 13                             0.059479     14400.0    2020.00
# 14                             0.059479     14400.0    2020.00
# 15                             0.059479     14400.0    2020.00
# 16                             0.059479     14400.0    2020.00
# 17                             0.059479     14400.0    2020.00
# 18                             0.059479     14400.0    2020.00
# 19                             0.059479     14400.0    2020.00
# 20                             0.059479     14400.0    2020.00
# 21                             0.059479     14400.0    2020.00
# 22                             0.059479     14400.0    2020.00
# 23                             0.059479     14400.0    2020.00
# 24                             0.069807     16500.0    4320.00
# 25                             0.069807     16500.0    4320.00
# 26                             0.069807     16500.0    4320.00
# 27                             0.069807     16500.0    4320.00
# 28                             0.069807     16500.0    4320.00
# 29                             0.069807     16500.0    4320.00
# 30                             0.069807     16500.0    4320.00
# 31                             0.069807     16500.0    4320.00
# 32                             0.069807     16500.0    4320.00
# 33                             0.069807     16500.0    4320.00
# 34                             0.069807     16500.0    4320.00
# 35                             0.069807     16500.0    4320.00
# 36                             0.063468     14700.0    2363.75
# 37                             0.063468     14700.0    2363.75
# 38                             0.063468     14700.0    2363.75
# 39                             0.063468     14700.0    2363.75
# 40                             0.063468     14700.0    2363.75
# 41                             0.063468     14700.0    2363.75
# 42                             0.063468     14700.0    2363.75
# 43                             0.063468     14700.0    2363.75
# 44                             0.063468     14700.0    2363.75
# 45                             0.063468     14700.0    2363.75
# 46                             0.063468     14700.0    2363.75
# 47                             0.063468     14700.0    2363.75
# 48                             0.062662     16200.0    2407.50
# 49                             0.062662     16200.0    2407.50
# 50                             0.062662     16200.0    2407.50
# 51                             0.062662     16200.0    2407.50
# 52                             0.062662     16200.0    2407.50
# 53                             0.062662     16200.0    2407.50
# 54                             0.062662     16200.0    2407.50
# 55                             0.062662     16200.0    2407.50
# 56                             0.062662     16200.0    2407.50
# 57                             0.062662     16200.0    2407.50
# 58                             0.062662     16200.0    2407.50
# 59                             0.062662     16200.0    2407.50
#
#     throughput_jobs_per_hour  scheduler_overhead_s  energy_per_job_wh
# 0                  11.520000              0.000021         262.625000
# 1                  11.520000              0.000021         262.625000
# 2                  11.520000              0.000021         262.625000
# 3                  11.520000              0.000021         262.625000
# 4                  11.520000              0.000021         262.625000
# 5                  11.520000              0.000021         262.625000
# 6                  11.755102              0.000021         262.625000
# 7                  11.755102              0.000021         262.625000
# 8                  11.755102              0.000021         262.625000
# 9                  11.755102              0.000021         262.625000
# 10                 11.755102              0.000021         262.625000
# 11                 11.755102              0.000021         262.625000
# 12                 12.000000              0.000021         253.250000
# 13                 12.000000              0.000021         253.250000
# 14                 12.000000              0.000021         253.250000
# 15                 12.000000              0.000021         253.250000
# 16                 12.000000              0.000021         253.250000
# 17                 12.000000              0.000021         253.250000
# 18                 12.000000              0.000021         253.250000
# 19                 12.000000              0.000021         253.250000
# 20                 12.000000              0.000021         253.250000
# 21                 12.000000              0.000021         253.250000
# 22                 12.000000              0.000021         253.250000
# 23                 12.000000              0.000021         253.250000
# 24                 10.472727              0.000021         279.687500
# 25                 10.472727              0.000042         279.687500
# 26                 10.472727              0.000021         279.687500
# 27                 10.472727              0.000021         279.687500
# 28                 10.472727              0.000021         279.687500
# 29                 10.472727              0.000021         279.687500
# 30                 10.472727              0.000021         279.687500
# 31                 10.472727              0.000021         279.687500
# 32                 10.472727              0.000021         279.687500
# 33                 10.472727              0.000021         279.687500
# 34                 10.472727              0.000021         279.687500
# 35                 10.472727              0.000021         279.687500
# 36                 11.755102              0.000021         262.625000
# 37                 11.755102              0.000021         262.625000
# 38                 11.755102              0.000021         262.625000
# 39                 11.755102              0.000021         262.625000
# 40                 11.755102              0.000021         262.625000
# 41                 11.755102              0.000021         262.625000
# 42                 11.755102              0.000021         262.625000
# 43                 11.755102              0.000021         262.625000
# 44                 11.755102              0.000021         262.625000
# 45                 11.755102              0.000021         262.625000
# 46                 11.755102              0.000021         262.625000
# 47                 11.755102              0.000021         262.625000
# 48                 10.666667              0.000021         264.229167
# 49                 10.666667              0.000021         264.229167
# 50                 10.666667              0.000021         264.229167
# 51                 10.666667              0.000021         264.229167
# 52                 10.666667              0.000021         264.229167
# 53                 10.666667              0.000021         264.229167
# 54                 10.666667              0.000021         264.229167
# 55                 10.666667              0.000021         264.229167
# 56                 10.666667              0.000021         264.229167
# 57                 10.666667              0.000021         264.229167
# 58                 10.666667              0.000021         264.229167
# 59                 10.666667              0.000021         264.229167

# %% [markdown]
# ### Scheduler decision mix
#
# Aggregate the number of scheduling decisions by policy and environment to verify the replay covers the intended scenarios.

# %%
decision_counts = (
    combined.groupby(["source", "policy"], dropna=False)["job_id"]
    .count()
    .reset_index(name="decisions")
)

if decision_counts.empty:
    decision_counts
else:
    pivot_counts = (
        decision_counts
        .pivot(index="policy", columns="source", values="decisions")
        .fillna(0)
        .sort_index()
    )
    fig, ax = plt.subplots(figsize=(8, 5))
    pivot_counts.plot(kind="bar", ax=ax)
    ax.set_ylabel("Decisions")
    ax.set_title("Scheduler decisions by source")
    ax.legend(title="Source")
    fig.tight_layout()
    decisions_plot_path = figures_dir / "scheduler_decisions_by_source.png"
    fig.savefig(decisions_plot_path, dpi=300)
    pivot_counts, decisions_plot_path

# %% [markdown]
# ## 7. Visual comparisons
#
# We now contrast the average wait times and carbon footprint of each policy. The
# Kubernetes replay (engine) is highlighted separately; because the sampled trace only
# contains fallback decisions, the wait/runtime metrics stay undefined (`NaN`).

# %%
fig, ax = plt.subplots(figsize=(8, 5))

sim_points = sim_summary_metrics.sort_values("total_ci_cost_g_reported")
ax.scatter(
    sim_points["total_ci_cost_g_reported"],
    sim_points["avg_wait_s_reported"],
    label="Simulator policies",
    c="tab:blue",
)
for _, row in sim_points.iterrows():
    ax.annotate(
        row["policy"],
        (row["total_ci_cost_g_reported"], row["avg_wait_s_reported"]),
        textcoords="offset points",
        xytext=(5, 5),
    )

k8_summary = summary_by_source.query("source == 'kubernetes'")
if not k8_summary.empty:
    ax.scatter(
        k8_summary["total_ci_cost_g"],
        k8_summary["avg_wait_s"],
        label="Kubernetes replay",
        marker="s",
        c="tab:orange",
        s=90,
    )
    for _, row in k8_summary.iterrows():
        ax.annotate(
            f"k8s:{row['policy']}",
            (row["total_ci_cost_g"], row["avg_wait_s"]),
            textcoords="offset points",
            xytext=(5, -12),
        )

ax.set_xlabel("Total CI cost (g)")
ax.set_ylabel("Average wait (s)")
ax.set_title("Carbon vs. wait trade-offs")
ax.legend()
fig.tight_layout()

tradeoff_path = figures_dir / "carbon_vs_wait_tradeoff.png"
fig.savefig(tradeoff_path, dpi=300)
tradeoff_path
# Out:
# PosixPath('/home/goncalo/KubeEnergyScheduler/analysis/figures/carbon_vs_wait_tradeoff.png')

# %% [markdown]
# ## 8. Pareto-front analysis
#
# The Pareto filter isolates the policies that are non-dominated with respect to
# (total carbon, average wait). These are the options worth keeping when searching
# for better baselines or new algorithms.

# %%
pareto_metrics = sim_points[["total_ci_cost_g_reported", "avg_wait_s_reported"]].to_numpy()
mask = pareto_front(pareto_metrics)
pareto_candidates = sim_points.loc[mask].copy()
pareto_candidates
# Out:
#    source_jobs     policy   jobs  completed_jobs  completion_ratio  \
# 12   simulator  hetpolicy  576.0           576.0               1.0
# 13   simulator  hetpolicy  576.0           576.0               1.0
# 14   simulator  hetpolicy  576.0           576.0               1.0
# 15   simulator  hetpolicy  576.0           576.0               1.0
# 19   simulator  hetpolicy  576.0           576.0               1.0
# 18   simulator  hetpolicy  576.0           576.0               1.0
# 17   simulator  hetpolicy  576.0           576.0               1.0
# 16   simulator  hetpolicy  576.0           576.0               1.0
# 23   simulator  hetpolicy  576.0           576.0               1.0
# 22   simulator  hetpolicy  576.0           576.0               1.0
# 21   simulator  hetpolicy  576.0           576.0               1.0
# 20   simulator  hetpolicy  576.0           576.0               1.0
#
#     fallback_ratio  total_ci_cost_g_jobs  avg_ci_per_job_g_jobs  \
# 12             NaN             34.259856               0.059479
# 13             NaN             34.259856               0.059479
# 14             NaN             34.259856               0.059479
# 15             NaN             34.259856               0.059479
# 19             NaN             34.259856               0.059479
# 18             NaN             34.259856               0.059479
# 17             NaN             34.259856               0.059479
# 16             NaN             34.259856               0.059479
# 23             NaN             34.259856               0.059479
# 22             NaN             34.259856               0.059479
# 21             NaN             34.259856               0.059479
# 20             NaN             34.259856               0.059479
#
#     avg_wait_s_jobs  avg_runtime_s  ...  elapsed_ms  num_jobs  alpha  beta  \
# 12           2020.0         1487.5  ...         1.0        48   0.58  0.21
# 13           2020.0         1487.5  ...         1.0        48   0.58  0.21
# 14           2020.0         1487.5  ...         1.0        48   0.58  0.21
# 15           2020.0         1487.5  ...         1.0        48   0.58  0.21
# 19           2020.0         1487.5  ...         1.0        48   0.58  0.21
# 18           2020.0         1487.5  ...         1.0        48   0.58  0.21
# 17           2020.0         1487.5  ...         1.0        48   0.58  0.21
# 16           2020.0         1487.5  ...         1.0        48   0.58  0.21
# 23           2020.0         1487.5  ...         1.0        48   0.58  0.21
# 22           2020.0         1487.5  ...         1.0        48   0.58  0.21
# 21           2020.0         1487.5  ...         1.0        48   0.58  0.21
# 20           2020.0         1487.5  ...         1.0        48   0.58  0.21
#
#     gamma  alpha_mass  lookahead_min  duration_scale  duration_overrides  \
# 12   0.21         1.0              0             1.0                 NaN
# 13   0.21         1.0              0             1.0                 NaN
# 14   0.21         1.0              0             1.0                 NaN
# 15   0.21         1.0              0             1.0                 NaN
# 19   0.21         1.0              0             1.0                 NaN
# 18   0.21         1.0              0             1.0                 NaN
# 17   0.21         1.0              0             1.0                 NaN
# 16   0.21         1.0              0             1.0                 NaN
# 23   0.21         1.0              0             1.0                 NaN
# 22   0.21         1.0              0             1.0                 NaN
# 21   0.21         1.0              0             1.0                 NaN
# 20   0.21         1.0              0             1.0                 NaN
#
#     source_reported
# 12        simulator
# 13        simulator
# 14        simulator
# 15        simulator
# 19        simulator
# 18        simulator
# 17        simulator
# 16        simulator
# 23        simulator
# 22        simulator
# 21        simulator
# 20        simulator
#
# [12 rows x 28 columns]

# %%
tables_dir = figures_dir.parent / "tables"
tables_dir.mkdir(parents=True, exist_ok=True)

pareto_latex_path = tables_dir / "pareto_front.tex"
if pareto_candidates.empty:
    pareto_latex_path.write_text("% Pareto front empty\n")
else:
    pareto_candidates.to_latex(
        pareto_latex_path,
        index=False,
        float_format="%.3f",
        caption="Pareto front across simulator policies (carbon vs. wait).",
        label="tab:pareto_front",
    )

policy_pareto_latex_path = tables_dir / "policy_pareto_front.tex"
if per_policy_pareto_table.empty:
    policy_pareto_latex_path.write_text("% Policy-specific Pareto fronts empty\n")
else:
    policy_export = per_policy_pareto_table.rename(
        columns={
            "ci_weight": "ci_weight",
            "batch_size": "batch_size",
            "total_ci_cost_g": "total_ci_cost_g",
            "avg_wait_s": "avg_wait_s",
        }
    )
    policy_export.to_latex(
        policy_pareto_latex_path,
        index=False,
        float_format="%.3f",
        caption="Policy-level Pareto fronts (total carbon vs. average wait).",
        label="tab:policy_pareto_front",
    )

pareto_latex_path, policy_pareto_latex_path
# Out:
# (PosixPath('/home/goncalo/KubeEnergyScheduler/analysis/tables/pareto_front.tex'),
#  PosixPath('/home/goncalo/KubeEnergyScheduler/analysis/tables/policy_pareto_front.tex'))

# %%
fig, ax = plt.subplots(figsize=(8, 5))

ax.scatter(
    sim_points["total_ci_cost_g_reported"],
    sim_points["avg_wait_s_reported"],
    color="lightgray",
    label="All policies",
)
ax.scatter(
    pareto_candidates["total_ci_cost_g_reported"],
    pareto_candidates["avg_wait_s_reported"],
    color="tab:green",
    label="Pareto front",
)
ax.plot(
    pareto_candidates["total_ci_cost_g_reported"],
    pareto_candidates["avg_wait_s_reported"],
    color="tab:green",
    linestyle="--",
    linewidth=1,
)
for _, row in pareto_candidates.iterrows():
    ax.annotate(
        row["policy"],
        (row["total_ci_cost_g_reported"], row["avg_wait_s_reported"]),
        textcoords="offset points",
        xytext=(4, 6),
    )

ax.set_xlabel("Total CI cost (g)")
ax.set_ylabel("Average wait (s)")
ax.set_title("Simulator Pareto front")
ax.legend()
fig.tight_layout()

pareto_path = figures_dir / "simulator_pareto_front.png"
fig.savefig(pareto_path, dpi=300)
pareto_path
# Out:
# PosixPath('/home/goncalo/KubeEnergyScheduler/analysis/figures/simulator_pareto_front.png')

# %% [markdown]
# ## 9. Hooks for contextual metrics (optional)
#
# The design document suggests extending the notebook with contextual indicators
# (power traces, forecasts). When Prometheus endpoints become available, inject the
# queries here and join on the `submit/start/end` timestamps stored in `combined`.

# %% [markdown]
# ## 10. Conclusions
#
# The consolidated tables confirm that the simulator emits complete traces for all
# policies, whereas the sampled Kubernetes replay currently falls back on every job.
# That discrepancy highlights the need for additional cluster-side debugging before
# using the replay as a baseline. The Pareto front nonetheless identifies the
# non-dominated simulator policies, informing which schedulers to evolve or replace
# when collecting new baselines.
