# %% [markdown]
# # Kubernetes vs. Simulator Evaluation
#
# This notebook reproduces the final evaluation cycle combining the Kubernetes replay
# and the simulator runs. It loads the exported scheduling traces, harmonises the
# schema, computes summary metrics, and visualises the trade-offs across policies with
# Pareto-front analysis.
#
# The workflow follows the architecture notes in Chapter 5.3.2 of the design document:
#
# 1. Select the runs and fetch the traces.
# 2. Harmonise the per-job schema and enrich it with timing features.
# 3. Optionally pull contextual metrics (left as hooks for Prometheus integration).
# 4. Produce visual comparisons and Pareto-front inspection.

# %% [markdown]
# ## 1. Imports and helper utilities
#
# The helpers below keep the notebook self-contained: they resolve the repository
# root automatically, standardise datetime conversions, and expose a Pareto-front
# filter for the multi-objective analysis.

# %%
from __future__ import annotations

from pathlib import Path
from typing import List

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io
import json
import re
from collections import Counter
from textwrap import dedent

plt.style.use("seaborn-v0_8")


def find_repo_root(start: Path | None = None) -> Path:
    start = Path(start or Path.cwd()).resolve()
    for parent in [start, *start.parents]:
        if (parent / ".git").exists():
            return parent
    raise RuntimeError("Could not locate repository root from" f" {start}")


def safe_to_datetime(series: pd.Series) -> pd.Series:
    # Convert string timestamps to timezone-aware pandas datetimes. Placeholder
    # values such as 0001-01-01 are mapped to NaT so downstream metrics can drop them.
    cleaned = series.replace({"": pd.NA, "0001-01-01T00:00:00Z": pd.NA})
    return pd.to_datetime(cleaned, utc=True, errors="coerce")


def compute_wait_seconds(submit: pd.Series, start: pd.Series) -> pd.Series:
    wait = (start - submit).dt.total_seconds()
    return wait


def compute_runtime_seconds(start: pd.Series, end: pd.Series) -> pd.Series:
    runtime = (end - start).dt.total_seconds()
    return runtime


def pareto_front(points: np.ndarray) -> np.ndarray:
    # Return a boolean mask for the Pareto-efficient points (minimisation).
    if points.ndim != 2:
        raise ValueError("Pareto front expects a 2D array")
    n_points = points.shape[0]
    is_efficient = np.ones(n_points, dtype=bool)
    for i in range(n_points):
        if not is_efficient[i]:
            continue
        dominated = np.all(points <= points[i], axis=1) & np.any(points < points[i], axis=1)
        is_efficient &= ~dominated
    return is_efficient


repo_root = find_repo_root()
repo_root
# Out:
# PosixPath('/home/goncalo/KubeEnergyScheduler')

# %% [markdown]
# ## 2. Locate experiment artefacts
#
# Both the simulator and the Kubernetes replay export CSV/JSON artefacts. Update the
# paths below if you want to compare different runs.

# %%
# Simulator artefacts (per-job traces + summary metrics)
sim_dir = repo_root / "kubenergysched" / "results_latest"
sim_summary_path = sim_dir / "summary.csv"

# Kubernetes replay decisions (JSONL + optional CSV projection)
k8_decisions_jsonl = repo_root / "decisions.jsonl"
k8_decisions_csv = repo_root / "decisions.csv"

sim_dir, sim_summary_path, k8_decisions_jsonl, k8_decisions_csv
# Out:
# (PosixPath('/home/goncalo/KubeEnergyScheduler/kubenergysched/results_latest'),
#  PosixPath('/home/goncalo/KubeEnergyScheduler/kubenergysched/results_latest/summary.csv'),
#  PosixPath('/home/goncalo/KubeEnergyScheduler/decisions.jsonl'),
#  PosixPath('/home/goncalo/KubeEnergyScheduler/decisions.csv'))

# %% [markdown]
# ## 3. Load simulator traces
#
# The simulator stores one CSV per scheduler/policy configuration with per-job
# records. We consolidate them into a single `DataFrame` and derive the wait/runtime
# features required for the comparisons. The aggregated metrics are loaded from the
# `summary.csv` file emitted at the end of the simulation batch.

# %%
sim_per_job_frames: List[pd.DataFrame] = []

for csv_path in sorted(sim_dir.glob("*_results.csv")):
    if csv_path.name == "summary.csv":
        continue
    df = pd.read_csv(csv_path)
    # Ensure the common schema
    df["submit"] = pd.to_datetime(df["submit"], utc=True, errors="coerce")
    df["start"] = pd.to_datetime(df["start"], utc=True, errors="coerce")
    df["end"] = pd.to_datetime(df["end"], utc=True, errors="coerce")
    df["wait_s"] = df["wait_ms"].astype(float) / 1000.0
    df["runtime_s"] = compute_runtime_seconds(df["start"], df["end"])
    df["source"] = "simulator"

    # Add identifiers extracted from the filename (policy + configuration)
    base_name, ci_weight, batch_size, _ = csv_path.stem.rsplit("_", 3)
    df["policy"] = base_name
    df["ci_weight"] = float(ci_weight)
    df["batch_size"] = int(batch_size)
    sim_per_job_frames.append(df)

sim_per_job = pd.concat(sim_per_job_frames, ignore_index=True)
sim_per_job.head()
# Out:
#           sched job_id     node                    submit  \
# 0  carbonscaler  job-0    gpu-0 2025-10-19 15:00:00+00:00
# 1  carbonscaler  job-1  burst-0 2025-10-19 15:00:00+00:00
# 2  carbonscaler  job-2  burst-1 2025-10-19 15:00:00+00:00
# 3  carbonscaler  job-3  small-0 2025-10-19 15:00:03+00:00
# 4  carbonscaler  job-4    med-0 2025-10-19 15:00:04+00:00
#
#                                 start                                 end  \
# 0 2025-10-20 12:13:49.070536986+00:00 2025-10-20 12:15:54.070536986+00:00
# 1 2025-10-20 12:13:49.070536986+00:00 2025-10-20 12:23:35.070536986+00:00
# 2 2025-10-20 12:13:49.070536986+00:00 2025-10-20 12:17:16.070536986+00:00
# 3 2025-10-20 12:13:49.070536986+00:00 2025-10-20 12:14:31.070536986+00:00
# 4 2025-10-20 12:13:49.070536986+00:00 2025-10-20 12:22:55.070536986+00:00
#
#     wait_ms   ci_cost    wait_s  runtime_s     source        policy  \
# 0  76429070  0.000497  76429.07      125.0  simulator  carbonscaler
# 1  76429070  0.004712  76429.07      586.0  simulator  carbonscaler
# 2  76429070  0.004591  76429.07      207.0  simulator  carbonscaler
# 3  76426070  0.000169  76426.07       42.0  simulator  carbonscaler
# 4  76425070  0.006199  76425.07      546.0  simulator  carbonscaler
#
#    ci_weight  batch_size
# 0       0.05         128
# 1       0.05         128
# 2       0.05         128
# 3       0.05         128
# 4       0.05         128

# %%
sim_summary = pd.read_csv(sim_summary_path)
sim_summary["source"] = "simulator"
sim_summary
# Out:
#           policy  ci_weight  batch_size  total_ci_cost_g  avg_ci_per_job_g  \
# 0         engine       0.05          32         2.125371          0.002125
# 1             k8       0.05          32         2.143676          0.002144
# 2   carbonscaler       0.05          32         2.138741          0.002139
# 3    themis_base       0.05          32         2.132946          0.002133
# 4         engine       0.05         128         2.123727          0.002124
# 5             k8       0.05         128         2.143129          0.002143
# 6   carbonscaler       0.05         128         2.177376          0.002177
# 7    themis_base       0.05         128         2.135241          0.002135
# 8         engine       0.05         256         2.126348          0.002126
# 9             k8       0.05         256         2.141784          0.002142
# 10  carbonscaler       0.05         256         2.171161          0.002171
# 11   themis_base       0.05         256         2.138274          0.002138
# 12        engine       0.20          32         2.123119          0.002123
# 13            k8       0.20          32         2.134598          0.002135
# 14  carbonscaler       0.20          32         2.134739          0.002135
# 15   themis_base       0.20          32         2.134877          0.002135
# 16        engine       0.20         128         2.123251          0.002123
# 17            k8       0.20         128         2.135536          0.002136
# 18  carbonscaler       0.20         128         2.134196          0.002134
# 19   themis_base       0.20         128         2.137741          0.002138
# 20        engine       0.20         256         2.129909          0.002130
# 21            k8       0.20         256         2.136622          0.002137
# 22  carbonscaler       0.20         256         2.132139          0.002132
# 23   themis_base       0.20         256         2.138815          0.002139
# 24        engine       0.80          32         2.122359          0.002122
# 25            k8       0.80          32         2.140991          0.002141
# 26  carbonscaler       0.80          32         2.108632          0.002109
# 27   themis_base       0.80          32         2.132590          0.002133
# 28        engine       0.80         128         2.141130          0.002141
# 29            k8       0.80         128         2.145478          0.002145
# 30  carbonscaler       0.80         128         2.111668          0.002112
# 31   themis_base       0.80         128         2.137212          0.002137
# 32        engine       0.80         256         2.146012          0.002146
# 33            k8       0.80         256         2.142235          0.002142
# 34  carbonscaler       0.80         256         2.116475          0.002116
# 35   themis_base       0.80         256         2.130958          0.002131
# 36        engine       1.20          32         2.114386          0.002114
# 37            k8       1.20          32         2.140941          0.002141
# 38  carbonscaler       1.20          32         2.152351          0.002152
# 39   themis_base       1.20          32         2.128026          0.002128
# 40        engine       1.20         128         2.150987          0.002151
# 41            k8       1.20         128         2.143775          0.002144
# 42  carbonscaler       1.20         128         2.135091          0.002135
# 43   themis_base       1.20         128         2.128487          0.002128
# 44        engine       1.20         256         2.152601          0.002153
# 45            k8       1.20         256         2.140580          0.002141
# 46  carbonscaler       1.20         256         2.131320          0.002131
# 47   themis_base       1.20         256         2.129333          0.002129
#
#     cfp_g_per_cpu_hour  avg_wait_s  makespan_s  elapsed_ms  num_jobs  \
# 0             0.004568   82662.137     21945.0      2585.0      1000
# 1             0.004607   82720.924     20939.0       877.0      1000
# 2             0.004597   82782.683     21277.0      1187.0      1000
# 3             0.004584   82790.666     21639.0      1841.0      1000
# 4             0.004564   82673.585     21792.0      2717.0      1000
# 5             0.004606   82725.957     20939.0       931.0      1000
# 6             0.004680   82793.725     20956.0      1221.0      1000
# 7             0.004589   82733.072     21235.0      1731.0      1000
# 8             0.004570   82680.206     21792.0      2978.0      1000
# 9             0.004603   82732.843     20939.0      1000.0      1000
# 10            0.004666   82800.677     20956.0      1203.0      1000
# 11            0.004596   82740.004     21235.0      1766.0      1000
# 12            0.004563   82682.237     21945.0      2781.0      1000
# 13            0.004588   82741.219     20939.0       869.0      1000
# 14            0.004588   82803.126     21277.0      1332.0      1000
# 15            0.004588   82811.097     21639.0      1811.0      1000
# 16            0.004563   82693.986     21792.0      3093.0      1000
# 17            0.004590   82746.735     20939.0       933.0      1000
# 18            0.004587   82808.626     21277.0      1259.0      1000
# 19            0.004594   82753.884     21235.0      1629.0      1000
# 20            0.004578   82700.917     21792.0      2642.0      1000
# 21            0.004592   82753.214     20939.0      1078.0      1000
# 22            0.004582   82815.253     21277.0      1282.0      1000
# 23            0.004597   82760.540     21235.0      1795.0      1000
# 24            0.004561   82702.802     21945.0      3265.0      1000
# 25            0.004601   82762.270     20939.0      1238.0      1000
# 26            0.004532   82664.372     21481.0      1399.0      1000
# 27            0.004583   82832.926     21639.0      1968.0      1000
# 28            0.004602   82715.972     21792.0      2967.0      1000
# 29            0.004611   82768.594     20939.0       851.0      1000
# 30            0.004538   82769.667     21669.0      1313.0      1000
# 31            0.004593   82775.718     21235.0      1715.0      1000
# 32            0.004612   82722.840     21792.0      2890.0      1000
# 33            0.004604   82775.388     20939.0      1218.0      1000
# 34            0.004549   82776.830     21669.0      1307.0      1000
# 35            0.004580   82782.874     21235.0      1581.0      1000
# 36            0.004544   82724.924     21945.0      2891.0      1000
# 37            0.004601   82784.016     20939.0       970.0      1000
# 38            0.004626   82771.326     21362.0      1164.0      1000
# 39            0.004574   82853.823     21639.0      1738.0      1000
# 40            0.004623   82736.640     21792.0      2884.0      1000
# 41            0.004607   82789.182     20939.0       975.0      1000
# 42            0.004589   82694.552     21415.0      1590.0      1000
# 43            0.004575   82796.706     21235.0      1665.0      1000
# 44            0.004626   82743.773     21792.0      2968.0      1000
# 45            0.004601   82796.400     20939.0      1039.0      1000
# 46            0.004581   82701.834     21415.0      1262.0      1000
# 47            0.004576   82803.660     21235.0      1564.0      1000
#
#     alpha_mass  lookahead_min  duration_scale  duration_overrides     source
# 0          1.0              0             1.0                 NaN  simulator
# 1          1.0              0             1.0                 NaN  simulator
# 2          1.0              0             1.0                 NaN  simulator
# 3          1.0              0             1.0                 NaN  simulator
# 4          1.0              0             1.0                 NaN  simulator
# 5          1.0              0             1.0                 NaN  simulator
# 6          1.0              0             1.0                 NaN  simulator
# 7          1.0              0             1.0                 NaN  simulator
# 8          1.0              0             1.0                 NaN  simulator
# 9          1.0              0             1.0                 NaN  simulator
# 10         1.0              0             1.0                 NaN  simulator
# 11         1.0              0             1.0                 NaN  simulator
# 12         1.0              0             1.0                 NaN  simulator
# 13         1.0              0             1.0                 NaN  simulator
# 14         1.0              0             1.0                 NaN  simulator
# 15         1.0              0             1.0                 NaN  simulator
# 16         1.0              0             1.0                 NaN  simulator
# 17         1.0              0             1.0                 NaN  simulator
# 18         1.0              0             1.0                 NaN  simulator
# 19         1.0              0             1.0                 NaN  simulator
# 20         1.0              0             1.0                 NaN  simulator
# 21         1.0              0             1.0                 NaN  simulator
# 22         1.0              0             1.0                 NaN  simulator
# 23         1.0              0             1.0                 NaN  simulator
# 24         1.0              0             1.0                 NaN  simulator
# 25         1.0              0             1.0                 NaN  simulator
# 26         1.0              0             1.0                 NaN  simulator
# 27         1.0              0             1.0                 NaN  simulator
# 28         1.0              0             1.0                 NaN  simulator
# 29         1.0              0             1.0                 NaN  simulator
# 30         1.0              0             1.0                 NaN  simulator
# 31         1.0              0             1.0                 NaN  simulator
# 32         1.0              0             1.0                 NaN  simulator
# 33         1.0              0             1.0                 NaN  simulator
# 34         1.0              0             1.0                 NaN  simulator
# 35         1.0              0             1.0                 NaN  simulator
# 36         1.0              0             1.0                 NaN  simulator
# 37         1.0              0             1.0                 NaN  simulator
# 38         1.0              0             1.0                 NaN  simulator
# 39         1.0              0             1.0                 NaN  simulator
# 40         1.0              0             1.0                 NaN  simulator
# 41         1.0              0             1.0                 NaN  simulator
# 42         1.0              0             1.0                 NaN  simulator
# 43         1.0              0             1.0                 NaN  simulator
# 44         1.0              0             1.0                 NaN  simulator
# 45         1.0              0             1.0                 NaN  simulator
# 46         1.0              0             1.0                 NaN  simulator
# 47         1.0              0             1.0                 NaN  simulator

# %% [markdown]
# ## 4. Load Kubernetes replay decisions
#
# The controller exports one JSONL record per scheduling decision. The snippet below
# filters Kubernetes-native results (`result_type == "kub_result"`), converts the
# timestamps, and derives wait/runtime metrics to mirror the simulator schema.

# %%
k8_sources = []

if k8_decisions_jsonl.exists():
    k8_sources.append(k8_decisions_jsonl)

extra_k8_dirs = [
    repo_root / "analysis" / "k8s_runs",
    repo_root / "analysis" / "kubernetes_runs",
    repo_root / "k8s" / "runs",
    repo_root / "k8s" / "experiments",
]

for base_dir in extra_k8_dirs:
    if base_dir.exists():
        for candidate in sorted(base_dir.glob("**/*.jsonl")):
            if candidate.name.startswith("."):
                continue
            k8_sources.append(candidate)

seen_paths: set[Path] = set()
ordered_sources: list[Path] = []
for path in k8_sources:
    path = path.resolve()
    if not path.exists() or path in seen_paths:
        continue
    seen_paths.add(path)
    ordered_sources.append(path)


def _infer_run_id(path: Path) -> str:
    try:
        rel = path.relative_to(repo_root)
    except ValueError:
        rel = path
    parts: list[str] = []
    if rel.parent != Path('.'):
        parts.append(rel.parent.as_posix().replace('/', '__'))
    stem = rel.stem or rel.name
    if stem == "decisions" and rel.parent != Path('.'):
        stem = rel.parent.name
    parts.append(stem)
    run_id = "__".join([p for p in parts if p])
    return run_id or path.stem


def _load_sidecar_metadata(path: Path) -> dict:
    for meta_candidate in [
        path.with_suffix(".metadata.json"),
        path.with_suffix(".meta.json"),
        path.with_name("metadata.json"),
    ]:
        if meta_candidate.exists():
            try:
                return json.loads(meta_candidate.read_text())
            except Exception:
                return {}
    return {}


def _series_or_empty(df: pd.DataFrame, column: str) -> pd.Series:
    if column in df.columns:
        return df[column]
    return pd.Series(index=df.index, dtype=object)


k8_runs = []
for path in ordered_sources:
    try:
        df = pd.read_json(path, lines=True)
    except ValueError:
        continue
    df = df.query("result_type == 'kub_result'").copy()
    if df.empty:
        continue

    meta = _load_sidecar_metadata(path)
    run_id = str(meta.get("run_id") or _infer_run_id(path))
    label = str(meta.get("label") or meta.get("name") or run_id)

    for weight_key in ("theta_e", "theta_c"):
        if weight_key not in meta and weight_key in df.columns:
            values = df[weight_key].dropna().unique()
            if len(values) == 1:
                try:
                    meta[weight_key] = float(values[0])
                except (TypeError, ValueError):
                    meta[weight_key] = values[0]

    df["run_id"] = run_id
    df["run_label"] = label
    for key, value in meta.items():
        if key in {"run_id", "label", "name"}:
            continue
        df[key] = value

    k8_runs.append(
        {
            "path": path,
            "run_id": run_id,
            "label": label,
            "metadata": meta,
            "frame": df,
        }
    )

k8_run_metadata = {
    run["run_id"]: {k: v for k, v in run.items() if k != "frame"}
    for run in k8_runs
}

if k8_runs:
    k8_decisions = pd.concat([run["frame"] for run in k8_runs], ignore_index=True)
else:
    k8_decisions = pd.DataFrame(
        columns=[
            "result_type",
            "result_id",
            "scheduler",
            "source",
            "job_id",
            "site",
            "node",
            "e_norm",
            "c_norm",
            "cost",
            "theta_e",
            "theta_c",
            "forecast_used",
            "fallback",
            "reject_reason",
            "queued_at",
            "started_at",
            "ended_at",
            "run_id",
            "run_label",
        ]
    )

k8_decisions["submit"] = safe_to_datetime(_series_or_empty(k8_decisions, "queued_at"))
k8_decisions["start"] = safe_to_datetime(_series_or_empty(k8_decisions, "started_at"))
k8_decisions["end"] = safe_to_datetime(_series_or_empty(k8_decisions, "ended_at"))

k8_decisions["wait_s"] = compute_wait_seconds(k8_decisions["submit"], k8_decisions["start"])
k8_decisions["runtime_s"] = compute_runtime_seconds(k8_decisions["start"], k8_decisions["end"])

if "scheduler" in k8_decisions.columns:
    k8_decisions["policy"] = k8_decisions["scheduler"]
else:
    k8_decisions["policy"] = "unknown"
k8_decisions["source"] = "kubernetes"

k8_decisions[
    [
        "result_id",
        "run_id",
        "run_label",
        "scheduler",
        "job_id",
        "site",
        "node",
        "wait_s",
        "runtime_s",
        "fallback",
        "cost",
    ]
].head()
# Out:
#                                          result_id     run_id  run_label  \
# 0  kub_result_377704a9-aa1d-4c6d-bcb5-e4d70a75fd15  decisions  decisions
# 1  kub_result_c12af999-ebdb-40b4-a2da-49c8876d5796  decisions  decisions
# 2  kub_result_0264426d-50b3-4100-ac74-111d0588ee77  decisions  decisions
# 3  kub_result_6703b11e-1bec-42df-94e4-8538e9528bcf  decisions  decisions
# 4  kub_result_95d0ac44-b2fb-4aa3-b588-a5dbb5f40612  decisions  decisions
#
#   scheduler                                job_id site node  wait_s  \
# 0    engine  377704a9-aa1d-4c6d-bcb5-e4d70a75fd15               NaN
# 1    engine  c12af999-ebdb-40b4-a2da-49c8876d5796               NaN
# 2    engine  0264426d-50b3-4100-ac74-111d0588ee77               NaN
# 3    engine  6703b11e-1bec-42df-94e4-8538e9528bcf               NaN
# 4    engine  95d0ac44-b2fb-4aa3-b588-a5dbb5f40612               NaN
#
#    runtime_s  fallback  cost
# 0        NaN      True   0.0
# 1        NaN      True   0.0
# 2        NaN      True   0.0
# 3        NaN      True   0.0
# 4        NaN      True   0.0

# %% [markdown]
# ## 5. Harmonise schemas
#
# To compare the two environments we keep only the shared columns and annotate the
# origin. The helper below produces a tidy table that concatenates simulator and
# Kubernetes traces.

# %%
common_cols = [
    "source",
    "run_id",
    "run_label",
    "policy",
    "job_id",
    "site",
    "node",
    "submit",
    "start",
    "end",
    "wait_s",
    "runtime_s",
    "ci_cost",
]

sim_view = sim_per_job.copy()
if "policy" not in sim_view.columns:
    sim_view["policy"] = sim_view["sched"]
if "sched" in sim_view.columns:
    sim_view = sim_view.drop(columns=["sched"])
for col in ["site", "node"]:
    if col not in sim_view:
        sim_view[col] = pd.NA
sim_view["ci_cost"] = sim_view["ci_cost"].astype(float)
if "run_id" not in sim_view.columns:
    ci_str = sim_view.get("ci_weight", pd.Series(0.0, index=sim_view.index)).map(lambda v: f"{v:.2f}" if pd.notna(v) else "na")
    batch_str = sim_view.get("batch_size", pd.Series(0, index=sim_view.index)).astype(str)
    sim_view["run_id"] = (
        sim_view["policy"].astype(str)
        + "|ci="
        + ci_str
        + "|batch="
        + batch_str
    )
if "run_label" not in sim_view.columns:
    if {"ci_weight", "batch_size"}.issubset(sim_view.columns):
        sim_view["run_label"] = (
            sim_view["policy"].astype(str)
            + " (ci="
            + sim_view["ci_weight"].map(lambda v: f"{v:.2f}" if pd.notna(v) else "?")
            + ", batch="
            + sim_view["batch_size"].astype(str)
            + ")"
        )
    else:
        sim_view["run_label"] = sim_view["policy"].astype(str)

k8_view = k8_decisions.copy()
if "ci_cost" not in k8_view.columns:
    k8_view["ci_cost"] = k8_view.get("cost", 0.0)
if "run_id" not in k8_view.columns:
    k8_view["run_id"] = k8_view["policy"].astype(str)
if "run_label" not in k8_view.columns:
    label_cols = [col for col in ("run_label", "label") if col in k8_view.columns]
    if label_cols:
        k8_view["run_label"] = k8_view[label_cols[0]]
    else:
        k8_view["run_label"] = k8_view["run_id"]

combined = pd.concat(
    [sim_view[common_cols], k8_view[common_cols]],
    ignore_index=True,
    sort=False,
)
combined.head()
# Out:
#       source                          run_id  \
# 0  simulator  carbonscaler|ci=0.05|batch=128
# 1  simulator  carbonscaler|ci=0.05|batch=128
# 2  simulator  carbonscaler|ci=0.05|batch=128
# 3  simulator  carbonscaler|ci=0.05|batch=128
# 4  simulator  carbonscaler|ci=0.05|batch=128
#
#                            run_label        policy job_id site     node  \
# 0  carbonscaler (ci=0.05, batch=128)  carbonscaler  job-0  NaN    gpu-0
# 1  carbonscaler (ci=0.05, batch=128)  carbonscaler  job-1  NaN  burst-0
# 2  carbonscaler (ci=0.05, batch=128)  carbonscaler  job-2  NaN  burst-1
# 3  carbonscaler (ci=0.05, batch=128)  carbonscaler  job-3  NaN  small-0
# 4  carbonscaler (ci=0.05, batch=128)  carbonscaler  job-4  NaN    med-0
#
#                      submit                               start  \
# 0 2025-10-19 15:00:00+00:00 2025-10-20 12:13:49.070536986+00:00
# 1 2025-10-19 15:00:00+00:00 2025-10-20 12:13:49.070536986+00:00
# 2 2025-10-19 15:00:00+00:00 2025-10-20 12:13:49.070536986+00:00
# 3 2025-10-19 15:00:03+00:00 2025-10-20 12:13:49.070536986+00:00
# 4 2025-10-19 15:00:04+00:00 2025-10-20 12:13:49.070536986+00:00
#
#                                   end    wait_s  runtime_s   ci_cost
# 0 2025-10-20 12:15:54.070536986+00:00  76429.07      125.0  0.000497
# 1 2025-10-20 12:23:35.070536986+00:00  76429.07      586.0  0.004712
# 2 2025-10-20 12:17:16.070536986+00:00  76429.07      207.0  0.004591
# 3 2025-10-20 12:14:31.070536986+00:00  76426.07       42.0  0.000169
# 4 2025-10-20 12:22:55.070536986+00:00  76425.07      546.0  0.006199

# %% [markdown]
# ## 6. Summary metrics per environment
#
# The next cells compute aggregate indicators (number of jobs, completion ratio,
# carbon impact, wait time, fallback rate) to sanity-check the two datasets before
# digging into the Pareto analysis.

# %%
def summarise_jobs(df: pd.DataFrame) -> pd.Series:
    completed = df["end"].notna()
    submit = df["submit"].dropna()
    end_times = df.loc[completed, "end"]
    makespan = (end_times.max() - submit.min()).total_seconds() if not end_times.empty and not submit.empty else np.nan
    return pd.Series({
        "jobs": len(df),
        "completed_jobs": int(completed.sum()),
        "completion_ratio": completed.mean() if len(df) else np.nan,
        "fallback_ratio": df.get("fallback", pd.Series(dtype=float)).mean() if "fallback" in df else np.nan,
        "total_ci_cost_g": df["ci_cost"].sum(),
        "avg_ci_per_job_g": df["ci_cost"].mean(),
        "avg_wait_s": df["wait_s"].mean(),
        "avg_runtime_s": df["runtime_s"].mean(),
        "makespan_s": makespan,
    })
summary_by_source = (
    combined.groupby(["source", "run_id", "run_label", "policy"], dropna=False, group_keys=False)
    .apply(summarise_jobs, include_groups=False)
    .reset_index()
)
summary_by_source
# Out:
#         source                          run_id  \
# 0   kubernetes                       decisions
# 1    simulator  carbonscaler|ci=0.05|batch=128
# 2    simulator  carbonscaler|ci=0.05|batch=256
# 3    simulator   carbonscaler|ci=0.05|batch=32
# 4    simulator  carbonscaler|ci=0.20|batch=128
# 5    simulator  carbonscaler|ci=0.20|batch=256
# 6    simulator   carbonscaler|ci=0.20|batch=32
# 7    simulator  carbonscaler|ci=0.80|batch=128
# 8    simulator  carbonscaler|ci=0.80|batch=256
# 9    simulator   carbonscaler|ci=0.80|batch=32
# 10   simulator  carbonscaler|ci=1.20|batch=128
# 11   simulator  carbonscaler|ci=1.20|batch=256
# 12   simulator   carbonscaler|ci=1.20|batch=32
# 13   simulator        engine|ci=0.05|batch=128
# 14   simulator        engine|ci=0.05|batch=256
# 15   simulator         engine|ci=0.05|batch=32
# 16   simulator        engine|ci=0.20|batch=128
# 17   simulator        engine|ci=0.20|batch=256
# 18   simulator         engine|ci=0.20|batch=32
# 19   simulator        engine|ci=0.80|batch=128
# 20   simulator        engine|ci=0.80|batch=256
# 21   simulator         engine|ci=0.80|batch=32
# 22   simulator        engine|ci=1.20|batch=128
# 23   simulator        engine|ci=1.20|batch=256
# 24   simulator         engine|ci=1.20|batch=32
# 25   simulator            k8|ci=0.05|batch=128
# 26   simulator            k8|ci=0.05|batch=256
# 27   simulator             k8|ci=0.05|batch=32
# 28   simulator            k8|ci=0.20|batch=128
# 29   simulator            k8|ci=0.20|batch=256
# 30   simulator             k8|ci=0.20|batch=32
# 31   simulator            k8|ci=0.80|batch=128
# 32   simulator            k8|ci=0.80|batch=256
# 33   simulator             k8|ci=0.80|batch=32
# 34   simulator            k8|ci=1.20|batch=128
# 35   simulator            k8|ci=1.20|batch=256
# 36   simulator             k8|ci=1.20|batch=32
# 37   simulator   themis_base|ci=0.05|batch=128
# 38   simulator   themis_base|ci=0.05|batch=256
# 39   simulator    themis_base|ci=0.05|batch=32
# 40   simulator   themis_base|ci=0.20|batch=128
# 41   simulator   themis_base|ci=0.20|batch=256
# 42   simulator    themis_base|ci=0.20|batch=32
# 43   simulator   themis_base|ci=0.80|batch=128
# 44   simulator   themis_base|ci=0.80|batch=256
# 45   simulator    themis_base|ci=0.80|batch=32
# 46   simulator   themis_base|ci=1.20|batch=128
# 47   simulator   themis_base|ci=1.20|batch=256
# 48   simulator    themis_base|ci=1.20|batch=32
#
#                             run_label        policy    jobs  completed_jobs  \
# 0                           decisions        engine    70.0             0.0
# 1   carbonscaler (ci=0.05, batch=128)  carbonscaler  1000.0          1000.0
# 2   carbonscaler (ci=0.05, batch=256)  carbonscaler  1000.0          1000.0
# 3    carbonscaler (ci=0.05, batch=32)  carbonscaler  1000.0          1000.0
# 4   carbonscaler (ci=0.20, batch=128)  carbonscaler  1000.0          1000.0
# 5   carbonscaler (ci=0.20, batch=256)  carbonscaler  1000.0          1000.0
# 6    carbonscaler (ci=0.20, batch=32)  carbonscaler  1000.0          1000.0
# 7   carbonscaler (ci=0.80, batch=128)  carbonscaler  1000.0          1000.0
# 8   carbonscaler (ci=0.80, batch=256)  carbonscaler  1000.0          1000.0
# 9    carbonscaler (ci=0.80, batch=32)  carbonscaler  1000.0          1000.0
# 10  carbonscaler (ci=1.20, batch=128)  carbonscaler  1000.0          1000.0
# 11  carbonscaler (ci=1.20, batch=256)  carbonscaler  1000.0          1000.0
# 12   carbonscaler (ci=1.20, batch=32)  carbonscaler  1000.0          1000.0
# 13        engine (ci=0.05, batch=128)        engine  1000.0          1000.0
# 14        engine (ci=0.05, batch=256)        engine  1000.0          1000.0
# 15         engine (ci=0.05, batch=32)        engine  1000.0          1000.0
# 16        engine (ci=0.20, batch=128)        engine  1000.0          1000.0
# 17        engine (ci=0.20, batch=256)        engine  1000.0          1000.0
# 18         engine (ci=0.20, batch=32)        engine  1000.0          1000.0
# 19        engine (ci=0.80, batch=128)        engine  1000.0          1000.0
# 20        engine (ci=0.80, batch=256)        engine  1000.0          1000.0
# 21         engine (ci=0.80, batch=32)        engine  1000.0          1000.0
# 22        engine (ci=1.20, batch=128)        engine  1000.0          1000.0
# 23        engine (ci=1.20, batch=256)        engine  1000.0          1000.0
# 24         engine (ci=1.20, batch=32)        engine  1000.0          1000.0
# 25            k8 (ci=0.05, batch=128)            k8  1000.0          1000.0
# 26            k8 (ci=0.05, batch=256)            k8  1000.0          1000.0
# 27             k8 (ci=0.05, batch=32)            k8  1000.0          1000.0
# 28            k8 (ci=0.20, batch=128)            k8  1000.0          1000.0
# 29            k8 (ci=0.20, batch=256)            k8  1000.0          1000.0
# 30             k8 (ci=0.20, batch=32)            k8  1000.0          1000.0
# 31            k8 (ci=0.80, batch=128)            k8  1000.0          1000.0
# 32            k8 (ci=0.80, batch=256)            k8  1000.0          1000.0
# 33             k8 (ci=0.80, batch=32)            k8  1000.0          1000.0
# 34            k8 (ci=1.20, batch=128)            k8  1000.0          1000.0
# 35            k8 (ci=1.20, batch=256)            k8  1000.0          1000.0
# 36             k8 (ci=1.20, batch=32)            k8  1000.0          1000.0
# 37   themis_base (ci=0.05, batch=128)   themis_base  1000.0          1000.0
# 38   themis_base (ci=0.05, batch=256)   themis_base  1000.0          1000.0
# 39    themis_base (ci=0.05, batch=32)   themis_base  1000.0          1000.0
# 40   themis_base (ci=0.20, batch=128)   themis_base  1000.0          1000.0
# 41   themis_base (ci=0.20, batch=256)   themis_base  1000.0          1000.0
# 42    themis_base (ci=0.20, batch=32)   themis_base  1000.0          1000.0
# 43   themis_base (ci=0.80, batch=128)   themis_base  1000.0          1000.0
# 44   themis_base (ci=0.80, batch=256)   themis_base  1000.0          1000.0
# 45    themis_base (ci=0.80, batch=32)   themis_base  1000.0          1000.0
# 46   themis_base (ci=1.20, batch=128)   themis_base  1000.0          1000.0
# 47   themis_base (ci=1.20, batch=256)   themis_base  1000.0          1000.0
# 48    themis_base (ci=1.20, batch=32)   themis_base  1000.0          1000.0
#
#     completion_ratio  fallback_ratio  total_ci_cost_g  avg_ci_per_job_g  \
# 0                0.0             NaN         0.025691          0.000367
# 1                1.0             NaN         2.177373          0.002177
# 2                1.0             NaN         2.171155          0.002171
# 3                1.0             NaN         2.138732          0.002139
# 4                1.0             NaN         2.134185          0.002134
# 5                1.0             NaN         2.132127          0.002132
# 6                1.0             NaN         2.134732          0.002135
# 7                1.0             NaN         2.111658          0.002112
# 8                1.0             NaN         2.116482          0.002116
# 9                1.0             NaN         2.108617          0.002109
# 10               1.0             NaN         2.135088          0.002135
# 11               1.0             NaN         2.131312          0.002131
# 12               1.0             NaN         2.152341          0.002152
# 13               1.0             NaN         2.123727          0.002124
# 14               1.0             NaN         2.126355          0.002126
# 15               1.0             NaN         2.125365          0.002125
# 16               1.0             NaN         2.123258          0.002123
# 17               1.0             NaN         2.129922          0.002130
# 18               1.0             NaN         2.123119          0.002123
# 19               1.0             NaN         2.141129          0.002141
# 20               1.0             NaN         2.146006          0.002146
# 21               1.0             NaN         2.122362          0.002122
# 22               1.0             NaN         2.150989          0.002151
# 23               1.0             NaN         2.152596          0.002153
# 24               1.0             NaN         2.114374          0.002114
# 25               1.0             NaN         2.143119          0.002143
# 26               1.0             NaN         2.141777          0.002142
# 27               1.0             NaN         2.143667          0.002144
# 28               1.0             NaN         2.135520          0.002136
# 29               1.0             NaN         2.136615          0.002137
# 30               1.0             NaN         2.134594          0.002135
# 31               1.0             NaN         2.145479          0.002145
# 32               1.0             NaN         2.142222          0.002142
# 33               1.0             NaN         2.140983          0.002141
# 34               1.0             NaN         2.143776          0.002144
# 35               1.0             NaN         2.140586          0.002141
# 36               1.0             NaN         2.140934          0.002141
# 37               1.0             NaN         2.135240          0.002135
# 38               1.0             NaN         2.138257          0.002138
# 39               1.0             NaN         2.132938          0.002133
# 40               1.0             NaN         2.137731          0.002138
# 41               1.0             NaN         2.138803          0.002139
# 42               1.0             NaN         2.134864          0.002135
# 43               1.0             NaN         2.137198          0.002137
# 44               1.0             NaN         2.130955          0.002131
# 45               1.0             NaN         2.132574          0.002133
# 46               1.0             NaN         2.128493          0.002128
# 47               1.0             NaN         2.129329          0.002129
# 48               1.0             NaN         2.128011          0.002128
#
#     avg_wait_s  avg_runtime_s    makespan_s
# 0          NaN            NaN           NaN
# 1    82793.725        238.017  97385.070536
# 2    82800.677        238.017  97392.022023
# 3    82782.683        238.017  97699.370273
# 4    82808.626        238.017  97726.846158
# 5    82815.253        238.017  97733.473583
# 6    82803.126        238.017  97719.659577
# 7    82769.667        238.017  98140.623500
# 8    82776.830        238.017  98147.786123
# 9    82664.372        238.017  97945.075705
# 10   82694.552        238.017  97907.336156
# 11   82701.834        238.017  97914.618281
# 12   82771.326        238.017  97847.555275
# 13   82673.585        238.017  98217.410288
# 14   82680.206        238.017  98224.031603
# 15   82662.137        238.017  98363.898008
# 16   82693.986        238.017  98237.811830
# 17   82700.917        238.017  98244.742248
# 18   82682.237        238.017  98383.998674
# 19   82715.972        238.017  98259.797746
# 20   82722.840        238.017  98266.665578
# 21   82702.802        238.017  98404.563704
# 22   82736.640        238.017  98280.465889
# 23   82743.773        238.017  98287.598902
# 24   82724.924        238.017  98426.685173
# 25   82725.957        238.017  97367.131740
# 26   82732.843        238.017  97374.017551
# 27   82720.924        238.017  97360.488954
# 28   82746.735        238.017  97387.909815
# 29   82753.214        238.017  97394.388962
# 30   82741.219        238.017  97380.783892
# 31   82768.594        238.017  97409.768615
# 32   82775.388        238.017  97416.562786
# 33   82762.270        238.017  97401.834445
# 34   82789.182        238.017  97430.356483
# 35   82796.400        238.017  97437.574989
# 36   82784.016        238.017  97423.580567
# 37   82733.072        238.017  97665.296355
# 38   82740.004        238.017  97672.228350
# 39   82790.666        238.017  98062.565072
# 40   82753.884        238.017  97686.108971
# 41   82760.540        238.017  97692.764712
# 42   82811.097        238.017  98082.996422
# 43   82775.718        238.017  97707.942499
# 44   82782.874        238.017  97715.098024
# 45   82832.926        238.017  98104.825216
# 46   82796.706        238.017  97728.930012
# 47   82803.660        238.017  97735.884681
# 48   82853.823        238.017  98125.722830

# %% [markdown]
# The simulator additionally exposes rich metadata (configuration weights, elapsed
# simulation time) via `summary.csv`. Joining that file with the per-job aggregates
# helps confirm consistency and provides the inputs for the Pareto plot.

# %%
sim_summary_metrics = summary_by_source.query("source == 'simulator'").merge(
    sim_summary,
    on=["policy"],
    how="left",
    suffixes=("_jobs", "_reported"),
)
sim_summary_metrics = sim_summary_metrics.rename(
    columns={
        "total_ci_cost_g_jobs": "total_ci_cost_g_from_jobs",
        "avg_wait_s_jobs": "avg_wait_s_from_jobs",
        "total_ci_cost_g_reported": "total_ci_cost_g_reported",
        "avg_wait_s_reported": "avg_wait_s_reported",
    }
)
sim_summary_metrics[[
    "policy",
    "jobs",
    "total_ci_cost_g_from_jobs",
    "total_ci_cost_g_reported",
    "avg_wait_s_from_jobs",
    "avg_wait_s_reported",
]]
# Out:
#            policy    jobs  total_ci_cost_g_from_jobs  \
# 0    carbonscaler  1000.0                   2.177373
# 1    carbonscaler  1000.0                   2.177373
# 2    carbonscaler  1000.0                   2.177373
# 3    carbonscaler  1000.0                   2.177373
# 4    carbonscaler  1000.0                   2.177373
# ..            ...     ...                        ...
# 571   themis_base  1000.0                   2.128011
# 572   themis_base  1000.0                   2.128011
# 573   themis_base  1000.0                   2.128011
# 574   themis_base  1000.0                   2.128011
# 575   themis_base  1000.0                   2.128011
#
#      total_ci_cost_g_reported  avg_wait_s_from_jobs  avg_wait_s_reported
# 0                    2.138741             82793.725            82782.683
# 1                    2.177376             82793.725            82793.725
# 2                    2.171161             82793.725            82800.677
# 3                    2.134739             82793.725            82803.126
# 4                    2.134196             82793.725            82808.626
# ..                        ...                   ...                  ...
# 571                  2.137212             82853.823            82775.718
# 572                  2.130958             82853.823            82782.874
# 573                  2.128026             82853.823            82853.823
# 574                  2.128487             82853.823            82796.706
# 575                  2.129333             82853.823            82803.660
#
# [576 rows x 6 columns]

# %% [markdown]
# ## 7. Visual comparisons
#
# We now contrast the average wait times and carbon footprint of each policy. The
# Kubernetes replay (engine) is highlighted separately; because the sampled trace only
# contains fallback decisions, the wait/runtime metrics stay undefined (`NaN`).

# %%
fig, ax = plt.subplots(figsize=(8, 5))
sim_points = sim_summary_metrics.sort_values("total_ci_cost_g_from_jobs")
ax.scatter(
    sim_points["total_ci_cost_g_from_jobs"],
    sim_points["avg_wait_s_from_jobs"],
    label="Simulator policies",
    c="tab:blue",
)
for _, row in sim_points.iterrows():
    ax.annotate(row["policy"], (row["total_ci_cost_g_from_jobs"], row["avg_wait_s_from_jobs"]), textcoords="offset points", xytext=(5, 5))
k8_summary = summary_by_source.query("source == 'kubernetes'")
if not k8_summary.empty:
    ax.scatter(
        k8_summary["total_ci_cost_g"],
        k8_summary["avg_wait_s"],
        label="Kubernetes replay",
        marker="s",
        c="tab:orange",
        s=90,
    )
    for _, row in k8_summary.iterrows():
        ax.annotate(
            f"k8s:{row['policy']}",
            (row["total_ci_cost_g"], row["avg_wait_s"]),
            textcoords="offset points",
            xytext=(5, -12),
        )
ax.set_xlabel("Total CI cost (g)")
ax.set_ylabel("Average wait (s)")
ax.set_title("Carbon vs. wait trade-offs")
ax.legend()
plt.show()

# %% [markdown]
# ## 8. Pareto-front analysis
#
# The Pareto filter isolates the policies that are non-dominated with respect to
# (total carbon, average wait). These are the options worth keeping when searching
# for better baselines or new algorithms.

# %%
pareto_metrics = sim_points[["total_ci_cost_g_from_jobs", "avg_wait_s_from_jobs"]].to_numpy()
mask = pareto_front(pareto_metrics)
pareto_candidates = sim_points.loc[mask].copy()
pareto_candidates
# Out:
#     source_jobs                          run_id  \
# 571   simulator    themis_base|ci=1.20|batch=32
# 570   simulator    themis_base|ci=1.20|batch=32
# 567   simulator    themis_base|ci=1.20|batch=32
# 566   simulator    themis_base|ci=1.20|batch=32
# 573   simulator    themis_base|ci=1.20|batch=32
# 572   simulator    themis_base|ci=1.20|batch=32
# 575   simulator    themis_base|ci=1.20|batch=32
# 574   simulator    themis_base|ci=1.20|batch=32
# 568   simulator    themis_base|ci=1.20|batch=32
# 569   simulator    themis_base|ci=1.20|batch=32
# 565   simulator    themis_base|ci=1.20|batch=32
# 564   simulator    themis_base|ci=1.20|batch=32
# 528   simulator    themis_base|ci=0.80|batch=32
# 529   simulator    themis_base|ci=0.80|batch=32
# 537   simulator    themis_base|ci=0.80|batch=32
# 536   simulator    themis_base|ci=0.80|batch=32
# 532   simulator    themis_base|ci=0.80|batch=32
# 533   simulator    themis_base|ci=0.80|batch=32
# 531   simulator    themis_base|ci=0.80|batch=32
# 530   simulator    themis_base|ci=0.80|batch=32
# 539   simulator    themis_base|ci=0.80|batch=32
# 538   simulator    themis_base|ci=0.80|batch=32
# 534   simulator    themis_base|ci=0.80|batch=32
# 535   simulator    themis_base|ci=0.80|batch=32
# 502   simulator    themis_base|ci=0.20|batch=32
# 503   simulator    themis_base|ci=0.20|batch=32
# 497   simulator    themis_base|ci=0.20|batch=32
# 496   simulator    themis_base|ci=0.20|batch=32
# 499   simulator    themis_base|ci=0.20|batch=32
# 498   simulator    themis_base|ci=0.20|batch=32
# 492   simulator    themis_base|ci=0.20|batch=32
# 493   simulator    themis_base|ci=0.20|batch=32
# 494   simulator    themis_base|ci=0.20|batch=32
# 495   simulator    themis_base|ci=0.20|batch=32
# 500   simulator    themis_base|ci=0.20|batch=32
# 501   simulator    themis_base|ci=0.20|batch=32
# 15    simulator  carbonscaler|ci=0.05|batch=256
# 14    simulator  carbonscaler|ci=0.05|batch=256
# 13    simulator  carbonscaler|ci=0.05|batch=256
# 12    simulator  carbonscaler|ci=0.05|batch=256
# 19    simulator  carbonscaler|ci=0.05|batch=256
# 18    simulator  carbonscaler|ci=0.05|batch=256
# 17    simulator  carbonscaler|ci=0.05|batch=256
# 16    simulator  carbonscaler|ci=0.05|batch=256
# 23    simulator  carbonscaler|ci=0.05|batch=256
# 22    simulator  carbonscaler|ci=0.05|batch=256
# 21    simulator  carbonscaler|ci=0.05|batch=256
# 20    simulator  carbonscaler|ci=0.05|batch=256
# 11    simulator  carbonscaler|ci=0.05|batch=128
# 10    simulator  carbonscaler|ci=0.05|batch=128
# 9     simulator  carbonscaler|ci=0.05|batch=128
# 8     simulator  carbonscaler|ci=0.05|batch=128
# 7     simulator  carbonscaler|ci=0.05|batch=128
# 6     simulator  carbonscaler|ci=0.05|batch=128
# 5     simulator  carbonscaler|ci=0.05|batch=128
# 4     simulator  carbonscaler|ci=0.05|batch=128
# 3     simulator  carbonscaler|ci=0.05|batch=128
# 2     simulator  carbonscaler|ci=0.05|batch=128
# 1     simulator  carbonscaler|ci=0.05|batch=128
# 0     simulator  carbonscaler|ci=0.05|batch=128
#
#                              run_label        policy    jobs  completed_jobs  \
# 571    themis_base (ci=1.20, batch=32)   themis_base  1000.0          1000.0
# 570    themis_base (ci=1.20, batch=32)   themis_base  1000.0          1000.0
# 567    themis_base (ci=1.20, batch=32)   themis_base  1000.0          1000.0
# 566    themis_base (ci=1.20, batch=32)   themis_base  1000.0          1000.0
# 573    themis_base (ci=1.20, batch=32)   themis_base  1000.0          1000.0
# 572    themis_base (ci=1.20, batch=32)   themis_base  1000.0          1000.0
# 575    themis_base (ci=1.20, batch=32)   themis_base  1000.0          1000.0
# 574    themis_base (ci=1.20, batch=32)   themis_base  1000.0          1000.0
# 568    themis_base (ci=1.20, batch=32)   themis_base  1000.0          1000.0
# 569    themis_base (ci=1.20, batch=32)   themis_base  1000.0          1000.0
# 565    themis_base (ci=1.20, batch=32)   themis_base  1000.0          1000.0
# 564    themis_base (ci=1.20, batch=32)   themis_base  1000.0          1000.0
# 528    themis_base (ci=0.80, batch=32)   themis_base  1000.0          1000.0
# 529    themis_base (ci=0.80, batch=32)   themis_base  1000.0          1000.0
# 537    themis_base (ci=0.80, batch=32)   themis_base  1000.0          1000.0
# 536    themis_base (ci=0.80, batch=32)   themis_base  1000.0          1000.0
# 532    themis_base (ci=0.80, batch=32)   themis_base  1000.0          1000.0
# 533    themis_base (ci=0.80, batch=32)   themis_base  1000.0          1000.0
# 531    themis_base (ci=0.80, batch=32)   themis_base  1000.0          1000.0
# 530    themis_base (ci=0.80, batch=32)   themis_base  1000.0          1000.0
# 539    themis_base (ci=0.80, batch=32)   themis_base  1000.0          1000.0
# 538    themis_base (ci=0.80, batch=32)   themis_base  1000.0          1000.0
# 534    themis_base (ci=0.80, batch=32)   themis_base  1000.0          1000.0
# 535    themis_base (ci=0.80, batch=32)   themis_base  1000.0          1000.0
# 502    themis_base (ci=0.20, batch=32)   themis_base  1000.0          1000.0
# 503    themis_base (ci=0.20, batch=32)   themis_base  1000.0          1000.0
# 497    themis_base (ci=0.20, batch=32)   themis_base  1000.0          1000.0
# 496    themis_base (ci=0.20, batch=32)   themis_base  1000.0          1000.0
# 499    themis_base (ci=0.20, batch=32)   themis_base  1000.0          1000.0
# 498    themis_base (ci=0.20, batch=32)   themis_base  1000.0          1000.0
# 492    themis_base (ci=0.20, batch=32)   themis_base  1000.0          1000.0
# 493    themis_base (ci=0.20, batch=32)   themis_base  1000.0          1000.0
# 494    themis_base (ci=0.20, batch=32)   themis_base  1000.0          1000.0
# 495    themis_base (ci=0.20, batch=32)   themis_base  1000.0          1000.0
# 500    themis_base (ci=0.20, batch=32)   themis_base  1000.0          1000.0
# 501    themis_base (ci=0.20, batch=32)   themis_base  1000.0          1000.0
# 15   carbonscaler (ci=0.05, batch=256)  carbonscaler  1000.0          1000.0
# 14   carbonscaler (ci=0.05, batch=256)  carbonscaler  1000.0          1000.0
# 13   carbonscaler (ci=0.05, batch=256)  carbonscaler  1000.0          1000.0
# 12   carbonscaler (ci=0.05, batch=256)  carbonscaler  1000.0          1000.0
# 19   carbonscaler (ci=0.05, batch=256)  carbonscaler  1000.0          1000.0
# 18   carbonscaler (ci=0.05, batch=256)  carbonscaler  1000.0          1000.0
# 17   carbonscaler (ci=0.05, batch=256)  carbonscaler  1000.0          1000.0
# 16   carbonscaler (ci=0.05, batch=256)  carbonscaler  1000.0          1000.0
# 23   carbonscaler (ci=0.05, batch=256)  carbonscaler  1000.0          1000.0
# 22   carbonscaler (ci=0.05, batch=256)  carbonscaler  1000.0          1000.0
# 21   carbonscaler (ci=0.05, batch=256)  carbonscaler  1000.0          1000.0
# 20   carbonscaler (ci=0.05, batch=256)  carbonscaler  1000.0          1000.0
# 11   carbonscaler (ci=0.05, batch=128)  carbonscaler  1000.0          1000.0
# 10   carbonscaler (ci=0.05, batch=128)  carbonscaler  1000.0          1000.0
# 9    carbonscaler (ci=0.05, batch=128)  carbonscaler  1000.0          1000.0
# 8    carbonscaler (ci=0.05, batch=128)  carbonscaler  1000.0          1000.0
# 7    carbonscaler (ci=0.05, batch=128)  carbonscaler  1000.0          1000.0
# 6    carbonscaler (ci=0.05, batch=128)  carbonscaler  1000.0          1000.0
# 5    carbonscaler (ci=0.05, batch=128)  carbonscaler  1000.0          1000.0
# 4    carbonscaler (ci=0.05, batch=128)  carbonscaler  1000.0          1000.0
# 3    carbonscaler (ci=0.05, batch=128)  carbonscaler  1000.0          1000.0
# 2    carbonscaler (ci=0.05, batch=128)  carbonscaler  1000.0          1000.0
# 1    carbonscaler (ci=0.05, batch=128)  carbonscaler  1000.0          1000.0
# 0    carbonscaler (ci=0.05, batch=128)  carbonscaler  1000.0          1000.0
#
#      completion_ratio  fallback_ratio  total_ci_cost_g_from_jobs  \
# 571               1.0             NaN                   2.128011
# 570               1.0             NaN                   2.128011
# 567               1.0             NaN                   2.128011
# 566               1.0             NaN                   2.128011
# 573               1.0             NaN                   2.128011
# 572               1.0             NaN                   2.128011
# 575               1.0             NaN                   2.128011
# 574               1.0             NaN                   2.128011
# 568               1.0             NaN                   2.128011
# 569               1.0             NaN                   2.128011
# 565               1.0             NaN                   2.128011
# 564               1.0             NaN                   2.128011
# 528               1.0             NaN                   2.132574
# 529               1.0             NaN                   2.132574
# 537               1.0             NaN                   2.132574
# 536               1.0             NaN                   2.132574
# 532               1.0             NaN                   2.132574
# 533               1.0             NaN                   2.132574
# 531               1.0             NaN                   2.132574
# 530               1.0             NaN                   2.132574
# 539               1.0             NaN                   2.132574
# 538               1.0             NaN                   2.132574
# 534               1.0             NaN                   2.132574
# 535               1.0             NaN                   2.132574
# 502               1.0             NaN                   2.134864
# 503               1.0             NaN                   2.134864
# 497               1.0             NaN                   2.134864
# 496               1.0             NaN                   2.134864
# 499               1.0             NaN                   2.134864
# 498               1.0             NaN                   2.134864
# 492               1.0             NaN                   2.134864
# 493               1.0             NaN                   2.134864
# 494               1.0             NaN                   2.134864
# 495               1.0             NaN                   2.134864
# 500               1.0             NaN                   2.134864
# 501               1.0             NaN                   2.134864
# 15                1.0             NaN                   2.171155
# 14                1.0             NaN                   2.171155
# 13                1.0             NaN                   2.171155
# 12                1.0             NaN                   2.171155
# 19                1.0             NaN                   2.171155
# 18                1.0             NaN                   2.171155
# 17                1.0             NaN                   2.171155
# 16                1.0             NaN                   2.171155
# 23                1.0             NaN                   2.171155
# 22                1.0             NaN                   2.171155
# 21                1.0             NaN                   2.171155
# 20                1.0             NaN                   2.171155
# 11                1.0             NaN                   2.177373
# 10                1.0             NaN                   2.177373
# 9                 1.0             NaN                   2.177373
# 8                 1.0             NaN                   2.177373
# 7                 1.0             NaN                   2.177373
# 6                 1.0             NaN                   2.177373
# 5                 1.0             NaN                   2.177373
# 4                 1.0             NaN                   2.177373
# 3                 1.0             NaN                   2.177373
# 2                 1.0             NaN                   2.177373
# 1                 1.0             NaN                   2.177373
# 0                 1.0             NaN                   2.177373
#
#      avg_ci_per_job_g_jobs  ...  cfp_g_per_cpu_hour  avg_wait_s_reported  \
# 571               0.002128  ...            0.004593            82775.718
# 570               0.002128  ...            0.004583            82832.926
# 567               0.002128  ...            0.004588            82811.097
# 566               0.002128  ...            0.004596            82740.004
# 573               0.002128  ...            0.004574            82853.823
# 572               0.002128  ...            0.004580            82782.874
# 575               0.002128  ...            0.004576            82803.660
# 574               0.002128  ...            0.004575            82796.706
# 568               0.002128  ...            0.004594            82753.884
# 569               0.002128  ...            0.004597            82760.540
# 565               0.002128  ...            0.004589            82733.072
# 564               0.002128  ...            0.004584            82790.666
# 528               0.002133  ...            0.004584            82790.666
# 529               0.002133  ...            0.004589            82733.072
# 537               0.002133  ...            0.004574            82853.823
# 536               0.002133  ...            0.004580            82782.874
# 532               0.002133  ...            0.004594            82753.884
# 533               0.002133  ...            0.004597            82760.540
# 531               0.002133  ...            0.004588            82811.097
# 530               0.002133  ...            0.004596            82740.004
# 539               0.002133  ...            0.004576            82803.660
# 538               0.002133  ...            0.004575            82796.706
# 534               0.002133  ...            0.004583            82832.926
# 535               0.002133  ...            0.004593            82775.718
# 502               0.002135  ...            0.004575            82796.706
# 503               0.002135  ...            0.004576            82803.660
# 497               0.002135  ...            0.004597            82760.540
# 496               0.002135  ...            0.004594            82753.884
# 499               0.002135  ...            0.004593            82775.718
# 498               0.002135  ...            0.004583            82832.926
# 492               0.002135  ...            0.004584            82790.666
# 493               0.002135  ...            0.004589            82733.072
# 494               0.002135  ...            0.004596            82740.004
# 495               0.002135  ...            0.004588            82811.097
# 500               0.002135  ...            0.004580            82782.874
# 501               0.002135  ...            0.004574            82853.823
# 15                0.002171  ...            0.004588            82803.126
# 14                0.002171  ...            0.004666            82800.677
# 13                0.002171  ...            0.004680            82793.725
# 12                0.002171  ...            0.004597            82782.683
# 19                0.002171  ...            0.004538            82769.667
# 18                0.002171  ...            0.004532            82664.372
# 17                0.002171  ...            0.004582            82815.253
# 16                0.002171  ...            0.004587            82808.626
# 23                0.002171  ...            0.004581            82701.834
# 22                0.002171  ...            0.004589            82694.552
# 21                0.002171  ...            0.004626            82771.326
# 20                0.002171  ...            0.004549            82776.830
# 11                0.002177  ...            0.004581            82701.834
# 10                0.002177  ...            0.004589            82694.552
# 9                 0.002177  ...            0.004626            82771.326
# 8                 0.002177  ...            0.004549            82776.830
# 7                 0.002177  ...            0.004538            82769.667
# 6                 0.002177  ...            0.004532            82664.372
# 5                 0.002177  ...            0.004582            82815.253
# 4                 0.002177  ...            0.004587            82808.626
# 3                 0.002177  ...            0.004588            82803.126
# 2                 0.002177  ...            0.004666            82800.677
# 1                 0.002177  ...            0.004680            82793.725
# 0                 0.002177  ...            0.004597            82782.683
#
#      makespan_s_reported  elapsed_ms  num_jobs  alpha_mass  lookahead_min  \
# 571              21235.0      1715.0      1000         1.0              0
# 570              21639.0      1968.0      1000         1.0              0
# 567              21639.0      1811.0      1000         1.0              0
# 566              21235.0      1766.0      1000         1.0              0
# 573              21639.0      1738.0      1000         1.0              0
# 572              21235.0      1581.0      1000         1.0              0
# 575              21235.0      1564.0      1000         1.0              0
# 574              21235.0      1665.0      1000         1.0              0
# 568              21235.0      1629.0      1000         1.0              0
# 569              21235.0      1795.0      1000         1.0              0
# 565              21235.0      1731.0      1000         1.0              0
# 564              21639.0      1841.0      1000         1.0              0
# 528              21639.0      1841.0      1000         1.0              0
# 529              21235.0      1731.0      1000         1.0              0
# 537              21639.0      1738.0      1000         1.0              0
# 536              21235.0      1581.0      1000         1.0              0
# 532              21235.0      1629.0      1000         1.0              0
# 533              21235.0      1795.0      1000         1.0              0
# 531              21639.0      1811.0      1000         1.0              0
# 530              21235.0      1766.0      1000         1.0              0
# 539              21235.0      1564.0      1000         1.0              0
# 538              21235.0      1665.0      1000         1.0              0
# 534              21639.0      1968.0      1000         1.0              0
# 535              21235.0      1715.0      1000         1.0              0
# 502              21235.0      1665.0      1000         1.0              0
# 503              21235.0      1564.0      1000         1.0              0
# 497              21235.0      1795.0      1000         1.0              0
# 496              21235.0      1629.0      1000         1.0              0
# 499              21235.0      1715.0      1000         1.0              0
# 498              21639.0      1968.0      1000         1.0              0
# 492              21639.0      1841.0      1000         1.0              0
# 493              21235.0      1731.0      1000         1.0              0
# 494              21235.0      1766.0      1000         1.0              0
# 495              21639.0      1811.0      1000         1.0              0
# 500              21235.0      1581.0      1000         1.0              0
# 501              21639.0      1738.0      1000         1.0              0
# 15               21277.0      1332.0      1000         1.0              0
# 14               20956.0      1203.0      1000         1.0              0
# 13               20956.0      1221.0      1000         1.0              0
# 12               21277.0      1187.0      1000         1.0              0
# 19               21669.0      1313.0      1000         1.0              0
# 18               21481.0      1399.0      1000         1.0              0
# 17               21277.0      1282.0      1000         1.0              0
# 16               21277.0      1259.0      1000         1.0              0
# 23               21415.0      1262.0      1000         1.0              0
# 22               21415.0      1590.0      1000         1.0              0
# 21               21362.0      1164.0      1000         1.0              0
# 20               21669.0      1307.0      1000         1.0              0
# 11               21415.0      1262.0      1000         1.0              0
# 10               21415.0      1590.0      1000         1.0              0
# 9                21362.0      1164.0      1000         1.0              0
# 8                21669.0      1307.0      1000         1.0              0
# 7                21669.0      1313.0      1000         1.0              0
# 6                21481.0      1399.0      1000         1.0              0
# 5                21277.0      1282.0      1000         1.0              0
# 4                21277.0      1259.0      1000         1.0              0
# 3                21277.0      1332.0      1000         1.0              0
# 2                20956.0      1203.0      1000         1.0              0
# 1                20956.0      1221.0      1000         1.0              0
# 0                21277.0      1187.0      1000         1.0              0
#
#      duration_scale  duration_overrides  source_reported
# 571             1.0                 NaN        simulator
# 570             1.0                 NaN        simulator
# 567             1.0                 NaN        simulator
# 566             1.0                 NaN        simulator
# 573             1.0                 NaN        simulator
# 572             1.0                 NaN        simulator
# 575             1.0                 NaN        simulator
# 574             1.0                 NaN        simulator
# 568             1.0                 NaN        simulator
# 569             1.0                 NaN        simulator
# 565             1.0                 NaN        simulator
# 564             1.0                 NaN        simulator
# 528             1.0                 NaN        simulator
# 529             1.0                 NaN        simulator
# 537             1.0                 NaN        simulator
# 536             1.0                 NaN        simulator
# 532             1.0                 NaN        simulator
# 533             1.0                 NaN        simulator
# 531             1.0                 NaN        simulator
# 530             1.0                 NaN        simulator
# 539             1.0                 NaN        simulator
# 538             1.0                 NaN        simulator
# 534             1.0                 NaN        simulator
# 535             1.0                 NaN        simulator
# 502             1.0                 NaN        simulator
# 503             1.0                 NaN        simulator
# 497             1.0                 NaN        simulator
# 496             1.0                 NaN        simulator
# 499             1.0                 NaN        simulator
# 498             1.0                 NaN        simulator
# 492             1.0                 NaN        simulator
# 493             1.0                 NaN        simulator
# 494             1.0                 NaN        simulator
# 495             1.0                 NaN        simulator
# 500             1.0                 NaN        simulator
# 501             1.0                 NaN        simulator
# 15              1.0                 NaN        simulator
# 14              1.0                 NaN        simulator
# 13              1.0                 NaN        simulator
# 12              1.0                 NaN        simulator
# 19              1.0                 NaN        simulator
# 18              1.0                 NaN        simulator
# 17              1.0                 NaN        simulator
# 16              1.0                 NaN        simulator
# 23              1.0                 NaN        simulator
# 22              1.0                 NaN        simulator
# 21              1.0                 NaN        simulator
# 20              1.0                 NaN        simulator
# 11              1.0                 NaN        simulator
# 10              1.0                 NaN        simulator
# 9               1.0                 NaN        simulator
# 8               1.0                 NaN        simulator
# 7               1.0                 NaN        simulator
# 6               1.0                 NaN        simulator
# 5               1.0                 NaN        simulator
# 4               1.0                 NaN        simulator
# 3               1.0                 NaN        simulator
# 2               1.0                 NaN        simulator
# 1               1.0                 NaN        simulator
# 0               1.0                 NaN        simulator
#
# [60 rows x 27 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 5))
ax.scatter(sim_points["total_ci_cost_g_from_jobs"], sim_points["avg_wait_s_from_jobs"], color="lightgray", label="All policies")
ax.scatter(
    pareto_candidates["total_ci_cost_g_from_jobs"],
    pareto_candidates["avg_wait_s_from_jobs"],
    color="tab:green",
    label="Pareto front",
)
ax.plot(
    pareto_candidates["total_ci_cost_g_from_jobs"],
    pareto_candidates["avg_wait_s_from_jobs"],
    color="tab:green",
    linestyle="--",
    linewidth=1,
)
for _, row in pareto_candidates.iterrows():
    ax.annotate(row["policy"], (row["total_ci_cost_g_from_jobs"], row["avg_wait_s_from_jobs"]), textcoords="offset points", xytext=(4, 6))
ax.set_xlabel("Total CI cost (g)")
ax.set_ylabel("Average wait (s)")
ax.set_title("Simulator Pareto front")
ax.legend()
plt.show()

# %% [markdown]
# ## 9. Hooks for contextual metrics (optional)
#
# The design document suggests extending the notebook with contextual indicators
# (power traces, forecasts). When Prometheus endpoints become available, inject the
# queries here and join on the `submit/start/end` timestamps stored in `combined`.

# %% [markdown]
# ## 10. Conclusions
#
# The consolidated tables confirm that the simulator emits complete traces for all
# policies, whereas the sampled Kubernetes replay currently falls back on every job.
# That discrepancy highlights the need for additional cluster-side debugging before
# using the replay as a baseline. The Pareto front nonetheless identifies the
# non-dominated simulator policies, informing which schedulers to evolve or replace
# when collecting new baselines.

# %%
from IPython.display import display, Markdown

def pareto_to_latex(df: pd.DataFrame) -> str:
    df = df.reset_index(drop=True)

    def fmt(val, fmt_str="{:.1f}", missing="--"):
        if pd.isna(val):
            return missing
        return fmt_str.format(val)

    buf = io.StringIO()
    buf.write(dedent(r"""
    \begin{table}[h!]\centering
    \caption{Simulation Pareto set: non-dominated points in the SCI--Makespan plane. CFP is informative only.}\label{tab:pf-sim}
    \small
    \begin{tabular}{r|ccc|cccc|c}\hline
    \multicolumn{1}{c|}{\#} & \multicolumn{3}{c|}{\textbf{Objectives}} & \multicolumn{4}{c|}{\textbf{Configuration}} & \textbf{Approach}\\
     & SCI (kg) & Makespan (min) & CFP (\%) & $\alpha$ & $\beta$ & $\gamma$ & Horizon (min) & \\\hline
    """).strip()+"\n")

    approach_map = {
        "engine": "KESPolicy",
        "themis_base": "KESPolicy",
        "carbonscaler": "CarbonScaler",
        "k8": "K8s baseline",
    }

    for idx, row in df.iterrows():
        sci = fmt(row.get("total_ci_cost_g_from_jobs"))
        makespan = fmt(row.get("makespan_s_reported") / 60 if "makespan_s_reported" in row else np.nan)
        cfp = fmt(row.get("cfp_g_per_cpu_hour") * 100 if "cfp_g_per_cpu_hour" in row else np.nan)
        alpha = fmt(row.get("alpha_mass"), "{:.2f}")
        beta = fmt(row.get("ci_weight"), "{:.2f}")
        gamma = fmt(row.get("util_weight"), "{:.2f}")
        horizon = fmt(row.get("lookahead_min"), "{:.0f}")
        approach = approach_map.get(row.get("policy"), row.get("policy", "--"))

        buf.write(
            f"{idx + 1}  & {sci} & {makespan} & {cfp} "
            f"& {alpha} & {beta} & {gamma} & {horizon} & {approach} \\\\\n"
        )

    buf.write(r"\hline"+"\n\\end{tabular}\n\\end{table}")
    return buf.getvalue()

latex_table = pareto_to_latex(pareto_candidates)
display(Markdown(f"```latex\n{latex_table}\n```"))
# Out:
# ```latex
# \begin{table}[h!]\centering
# \caption{Simulation Pareto set: non-dominated points in the SCI--Makespan plane. CFP is informative only.}\label{tab:pf-sim}
# \small
# \begin{tabular}{r|ccc|cccc|c}\hline
# \multicolumn{1}{c|}{\#} & \multicolumn{3}{c|}{\textbf{Objectives}} & \multicolumn{4}{c|}{\textbf{Configuration}} & \textbf{Approach}\\
#  & SCI (kg) & Makespan (min) & CFP (\%) & $\alpha$ & $\beta$ & $\gamma$ & Horizon (min) & \\\hline
# 1  & 2.1 & 353.9 & 0.5 & 1.00 & 0.80 & -- & 0 & KESPolicy \\
# 2  & 2.1 & 360.6 & 0.5 & 1.00 & 0.80 & -- & 0 & KESPolicy \\
# 3  & 2.1 & 360.6 & 0.5 & 1.00 & 0.20 & -- & 0 & KESPolicy \\
# 4  & 2.1 & 353.9 & 0.5 & 1.00 & 0.05 & -- & 0 & KESPolicy \\
# 5  & 2.1 & 360.6 & 0.5 & 1.00 & 1.20 & -- & 0 & KESPolicy \\
# 6  & 2.1 & 353.9 & 0.5 & 1.00 & 0.80 & -- & 0 & KESPolicy \\
# 7  & 2.1 & 353.9 & 0.5 & 1.00 & 1.20 & -- & 0 & KESPolicy \\
# 8  & 2.1 & 353.9 & 0.5 & 1.00 & 1.20 & -- & 0 & KESPolicy \\
# 9  & 2.1 & 353.9 & 0.5 & 1.00 & 0.20 & -- & 0 & KESPolicy \\
# 10  & 2.1 & 353.9 & 0.5 & 1.00 & 0.20 & -- & 0 & KESPolicy \\
# 11  & 2.1 & 353.9 & 0.5 & 1.00 & 0.05 & -- & 0 & KESPolicy \\
# 12  & 2.1 & 360.6 & 0.5 & 1.00 & 0.05 & -- & 0 & KESPolicy \\
# 13  & 2.1 & 360.6 & 0.5 & 1.00 & 0.05 & -- & 0 & KESPolicy \\
# 14  & 2.1 & 353.9 & 0.5 & 1.00 & 0.05 & -- & 0 & KESPolicy \\
# 15  & 2.1 & 360.6 & 0.5 & 1.00 & 1.20 & -- & 0 & KESPolicy \\
# 16  & 2.1 & 353.9 & 0.5 & 1.00 & 0.80 & -- & 0 & KESPolicy \\
# 17  & 2.1 & 353.9 & 0.5 & 1.00 & 0.20 & -- & 0 & KESPolicy \\
# 18  & 2.1 & 353.9 & 0.5 & 1.00 & 0.20 & -- & 0 & KESPolicy \\
# 19  & 2.1 & 360.6 & 0.5 & 1.00 & 0.20 & -- & 0 & KESPolicy \\
# 20  & 2.1 & 353.9 & 0.5 & 1.00 & 0.05 & -- & 0 & KESPolicy \\
# 21  & 2.1 & 353.9 & 0.5 & 1.00 & 1.20 & -- & 0 & KESPolicy \\
# 22  & 2.1 & 353.9 & 0.5 & 1.00 & 1.20 & -- & 0 & KESPolicy \\
# 23  & 2.1 & 360.6 & 0.5 & 1.00 & 0.80 & -- & 0 & KESPolicy \\
# 24  & 2.1 & 353.9 & 0.5 & 1.00 & 0.80 & -- & 0 & KESPolicy \\
# 25  & 2.1 & 353.9 & 0.5 & 1.00 & 1.20 & -- & 0 & KESPolicy \\
# 26  & 2.1 & 353.9 & 0.5 & 1.00 & 1.20 & -- & 0 & KESPolicy \\
# 27  & 2.1 & 353.9 & 0.5 & 1.00 & 0.20 & -- & 0 & KESPolicy \\
# 28  & 2.1 & 353.9 & 0.5 & 1.00 & 0.20 & -- & 0 & KESPolicy \\
# 29  & 2.1 & 353.9 & 0.5 & 1.00 & 0.80 & -- & 0 & KESPolicy \\
# 30  & 2.1 & 360.6 & 0.5 & 1.00 & 0.80 & -- & 0 & KESPolicy \\
# 31  & 2.1 & 360.6 & 0.5 & 1.00 & 0.05 & -- & 0 & KESPolicy \\
# 32  & 2.1 & 353.9 & 0.5 & 1.00 & 0.05 & -- & 0 & KESPolicy \\
# 33  & 2.1 & 353.9 & 0.5 & 1.00 & 0.05 & -- & 0 & KESPolicy \\
# 34  & 2.1 & 360.6 & 0.5 & 1.00 & 0.20 & -- & 0 & KESPolicy \\
# 35  & 2.1 & 353.9 & 0.5 & 1.00 & 0.80 & -- & 0 & KESPolicy \\
# 36  & 2.1 & 360.6 & 0.5 & 1.00 & 1.20 & -- & 0 & KESPolicy \\
# 37  & 2.2 & 354.6 & 0.5 & 1.00 & 0.20 & -- & 0 & CarbonScaler \\
# 38  & 2.2 & 349.3 & 0.5 & 1.00 & 0.05 & -- & 0 & CarbonScaler \\
# 39  & 2.2 & 349.3 & 0.5 & 1.00 & 0.05 & -- & 0 & CarbonScaler \\
# 40  & 2.2 & 354.6 & 0.5 & 1.00 & 0.05 & -- & 0 & CarbonScaler \\
# 41  & 2.2 & 361.1 & 0.5 & 1.00 & 0.80 & -- & 0 & CarbonScaler \\
# 42  & 2.2 & 358.0 & 0.5 & 1.00 & 0.80 & -- & 0 & CarbonScaler \\
# 43  & 2.2 & 354.6 & 0.5 & 1.00 & 0.20 & -- & 0 & CarbonScaler \\
# 44  & 2.2 & 354.6 & 0.5 & 1.00 & 0.20 & -- & 0 & CarbonScaler \\
# 45  & 2.2 & 356.9 & 0.5 & 1.00 & 1.20 & -- & 0 & CarbonScaler \\
# 46  & 2.2 & 356.9 & 0.5 & 1.00 & 1.20 & -- & 0 & CarbonScaler \\
# 47  & 2.2 & 356.0 & 0.5 & 1.00 & 1.20 & -- & 0 & CarbonScaler \\
# 48  & 2.2 & 361.1 & 0.5 & 1.00 & 0.80 & -- & 0 & CarbonScaler \\
# 49  & 2.2 & 356.9 & 0.5 & 1.00 & 1.20 & -- & 0 & CarbonScaler \\
# 50  & 2.2 & 356.9 & 0.5 & 1.00 & 1.20 & -- & 0 & CarbonScaler \\
# 51  & 2.2 & 356.0 & 0.5 & 1.00 & 1.20 & -- & 0 & CarbonScaler \\
# 52  & 2.2 & 361.1 & 0.5 & 1.00 & 0.80 & -- & 0 & CarbonScaler \\
# 53  & 2.2 & 361.1 & 0.5 & 1.00 & 0.80 & -- & 0 & CarbonScaler \\
# 54  & 2.2 & 358.0 & 0.5 & 1.00 & 0.80 & -- & 0 & CarbonScaler \\
# 55  & 2.2 & 354.6 & 0.5 & 1.00 & 0.20 & -- & 0 & CarbonScaler \\
# 56  & 2.2 & 354.6 & 0.5 & 1.00 & 0.20 & -- & 0 & CarbonScaler \\
# 57  & 2.2 & 354.6 & 0.5 & 1.00 & 0.20 & -- & 0 & CarbonScaler \\
# 58  & 2.2 & 349.3 & 0.5 & 1.00 & 0.05 & -- & 0 & CarbonScaler \\
# 59  & 2.2 & 349.3 & 0.5 & 1.00 & 0.05 & -- & 0 & CarbonScaler \\
# 60  & 2.2 & 354.6 & 0.5 & 1.00 & 0.05 & -- & 0 & CarbonScaler \\
# \hline
# \end{tabular}
# \end{table}
# ```

# %%
def _unique_scalar(df: pd.DataFrame, column: str):
    if column not in df.columns:
        return None
    values = df[column].dropna().unique()
    if len(values) == 1:
        return values[0]
    return None


def _relative_to_repo(path: Path) -> str:
    try:
        rel = path.relative_to(repo_root)
        return rel.as_posix()
    except ValueError:
        return str(path)


k8_summary_rows: list[dict] = []
for run in k8_runs:
    run_id = run["run_id"]
    run_frame = run["frame"]
    run_summary = summary_by_source[
        (summary_by_source["source"] == "kubernetes")
        & (summary_by_source["run_id"] == run_id)
    ]
    if run_summary.empty:
        continue

    row = run_summary.iloc[0].to_dict()
    row.setdefault("run_label", run.get("label"))
    row["decisions_path"] = _relative_to_repo(run["path"])

    metadata = run.get("metadata", {})
    for key in [
        "theta_e",
        "theta_c",
        "ci_weight",
        "util_weight",
        "alpha_mass",
        "beta",
        "gamma",
        "lookahead_min",
        "horizon_min",
        "forecast_horizon_min",
    ]:
        value = metadata.get(key)
        if value is None:
            value = _unique_scalar(run_frame, key)
        if value is not None:
            row[key] = value

    if "site" in run_frame.columns:
        site_series = run_frame["site"].fillna("unassigned")
        counts = site_series.value_counts()
        row["site_mix"] = ", ".join(f"{site}:{count}" for site, count in counts.items())
        row["unique_sites"] = int(
            sum(1 for site in counts.index if site not in {"", "unassigned"})
        )
        if not counts.empty:
            row["primary_site"] = counts.idxmax()

    if "fallback" in run_frame.columns:
        fallback_bool = run_frame["fallback"].fillna(False).astype(bool)
        row["fallback_jobs"] = int(fallback_bool.sum())
        row["scheduled_jobs"] = int((~fallback_bool).sum())
        row["fallback_ratio_jobs"] = fallback_bool.mean()

    k8_summary_rows.append(row)

k8_summary_metrics = pd.DataFrame(k8_summary_rows)
k8_summary_metrics
# Out:
#        source     run_id  run_label  policy  jobs  completed_jobs  \
# 0  kubernetes  decisions  decisions  engine  70.0             0.0
#
#    completion_ratio  fallback_ratio  total_ci_cost_g  avg_ci_per_job_g  ...  \
# 0               0.0             NaN         0.025691          0.000367  ...
#
#    makespan_s   decisions_path  theta_e theta_c  site_mix  unique_sites  \
# 0         NaN  decisions.jsonl      0.5     0.5  :67, B:3             1
#
#   primary_site  fallback_jobs scheduled_jobs  fallback_ratio_jobs
# 0                          67              3             0.957143
#
# [1 rows x 22 columns]

# %%
output_dir = repo_root / "analysis" / "jupyter" / "output"
output_dir.mkdir(parents=True, exist_ok=True)

if not k8_summary_metrics.empty:
    k8_sorted = k8_summary_metrics.sort_values(
        ["total_ci_cost_g", "avg_wait_s"],
        ascending=[True, True],
    ).reset_index(drop=True)
    k8_sorted.to_csv(output_dir / "k8s_summary_metrics.csv", index=False)

    def kubernetes_summary_to_latex(df: pd.DataFrame) -> str:
        df = df.reset_index(drop=True)

        def fmt(val, fmt_str="{:.1f}", missing="--"):
            if pd.isna(val):
                return missing
            try:
                return fmt_str.format(val)
            except Exception:
                return str(val)

        buf = io.StringIO()
        buf.write(
            dedent(
                r"""
            \begin{table}[h!]\centering
            \caption{Kubernetes scheduling runs: non-dominated samples across policy weights.}\label{tab:pf-k8s}
            \small
            \begin{tabular}{r|ccc|cccc|c}\hline
            \multicolumn{1}{c|}{\#} & \multicolumn{3}{c|}{\textbf{Objectives}} & \multicolumn{4}{c|}{\textbf{Configuration}} & \textbf{Run}\\
             & SCI (kg) & Makespan (min) & Avg wait (s) & $\theta_e$ & $\theta_c$ & Fallback (\%) & Sites & Label\\\hline
            """
            ).strip() + "
"
        )

        for idx, row in df.iterrows():
            sci = fmt(row.get("total_ci_cost_g") / 1000.0)
            makespan = fmt(row.get("makespan_s") / 60.0)
            wait = fmt(row.get("avg_wait_s"))
            theta_e = fmt(row.get("theta_e"), "{:.2f}")
            theta_c = fmt(row.get("theta_c"), "{:.2f}")
            fallback_pct = fmt(row.get("fallback_ratio_jobs") * 100.0, "{:.1f}")
            sites = row.get("site_mix", "--")
            label = row.get("run_label", row.get("run_id", "--"))

            buf.write(
                f"{idx + 1} & {sci} & {makespan} & {wait} & {theta_e} & {theta_c} & {fallback_pct} & {sites} & {label} \\n"
            )

        buf.write("\\hline
\\end{tabular}
\\end{table}")
        return buf.getvalue()

    latex_k8 = kubernetes_summary_to_latex(k8_sorted)
    (output_dir / "k8s_summary_table.tex").write_text(latex_k8)
    display(Markdown(f"```latex
{latex_k8}
```"))
else:
    print("No Kubernetes runs detected for summary table.")
# Out:
#   Cell In[14], line 33
#     ).strip() + "
#                 ^
# SyntaxError: unterminated string literal (detected at line 33)

# %%
plot_output_dir = output_dir / "k8s_schedules"
plot_output_dir.mkdir(parents=True, exist_ok=True)

schedule_artifacts = []
for run in k8_runs:
    df = run["frame"].copy()
    if df.empty:
        continue

    ordered = df.sort_values(["submit", "job_id"], na_position="last").reset_index(drop=True)
    ordered["decision_idx"] = ordered.index

    site_series = ordered.get("site", pd.Series(index=ordered.index, dtype=object)).fillna("unassigned")
    site_series = site_series.replace({"": "unassigned"})

    if "fallback" in ordered.columns:
        site_series = site_series.mask(ordered["fallback"].fillna(False), "fallback")

    categories = list(dict.fromkeys(site_series.tolist()))
    if not categories:
        categories = ["unassigned"]
    category_positions = {cat: idx for idx, cat in enumerate(categories)}
    ordered["site_pos"] = site_series.map(category_positions)

    fallback_bool = (site_series == "fallback")
    scheduled_bool = ~fallback_bool

    fig, (ax_sites, ax_cum) = plt.subplots(2, 1, figsize=(10, 6), sharex=True)
    cmap = plt.get_cmap("tab20")
    colors = [cmap(category_positions[cat] % cmap.N) for cat in site_series]

    ax_sites.scatter(ordered["decision_idx"], ordered["site_pos"], c=colors, s=28, edgecolor="none")
    ax_sites.set_yticks(list(category_positions.values()), list(category_positions.keys()))
    ax_sites.set_ylabel("Site / outcome")
    ax_sites.set_title(f"Scheduling decisions: {run['label']}")

    ax_cum.plot(ordered["decision_idx"], scheduled_bool.cumsum(), label="Scheduled", color="tab:green")
    ax_cum.plot(ordered["decision_idx"], fallback_bool.cumsum(), label="Fallback", color="tab:red")
    ax_cum.set_xlabel("Decision index")
    ax_cum.set_ylabel("Cumulative jobs")
    ax_cum.legend(loc="upper left")

    fig.tight_layout()

    safe_run_id = run["run_id"].replace("/", "_").replace(" ", "_")
    plot_path = plot_output_dir / f"k8s_schedule_{safe_run_id}.png"
    fig.savefig(plot_path, dpi=150, bbox_inches="tight")
    plt.close(fig)

    schedule_artifacts.append(plot_path.relative_to(repo_root))

schedule_artifacts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 plot_output_dir = output_dir / "k8s_schedules"
#       2 plot_output_dir.mkdir(parents=True, exist_ok=True)
#       4 schedule_artifacts = []
#
# NameError: name 'output_dir' is not defined
