# %% [markdown]
# # Kubernetes vs. Simulator Evaluation
#
# This notebook reproduces the final evaluation cycle combining the Kubernetes replay
# and the simulator runs. It loads the exported scheduling traces, harmonises the
# schema, computes summary metrics, and visualises the trade-offs across policies with
# Pareto-front analysis.
#
# The workflow follows the architecture notes in Chapter 5.3.2 of the design document:
#
# 1. Select the runs and fetch the traces.
# 2. Harmonise the per-job schema and enrich it with timing features.
# 3. Optionally pull contextual metrics (left as hooks for Prometheus integration).
# 4. Produce visual comparisons and Pareto-front inspection.

# %% [markdown]
# ## 1. Imports and helper utilities
#
# The helpers below keep the notebook self-contained: they resolve the repository
# root automatically, standardise datetime conversions, and expose a Pareto-front
# filter for the multi-objective analysis.

# %%
from __future__ import annotations

from pathlib import Path
from typing import List

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8")


def find_repo_root(start: Path | None = None) -> Path:
    start = Path(start or Path.cwd()).resolve()
    for parent in [start, *start.parents]:
        if (parent / ".git").exists():
            return parent
    raise RuntimeError("Could not locate repository root from" f" {start}")


def safe_to_datetime(series: pd.Series) -> pd.Series:
    # Convert string timestamps to timezone-aware pandas datetimes. Placeholder
    # values such as 0001-01-01 are mapped to NaT so downstream metrics can drop them.
    cleaned = series.replace({"": pd.NA, "0001-01-01T00:00:00Z": pd.NA})
    return pd.to_datetime(cleaned, utc=True, errors="coerce")


def compute_wait_seconds(submit: pd.Series, start: pd.Series) -> pd.Series:
    wait = (start - submit).dt.total_seconds()
    return wait


def compute_runtime_seconds(start: pd.Series, end: pd.Series) -> pd.Series:
    runtime = (end - start).dt.total_seconds()
    return runtime


def pareto_front(points: np.ndarray) -> np.ndarray:
    # Return a boolean mask for the Pareto-efficient points (minimisation).
    if points.ndim != 2:
        raise ValueError("Pareto front expects a 2D array")
    n_points = points.shape[0]
    is_efficient = np.ones(n_points, dtype=bool)
    for i in range(n_points):
        if not is_efficient[i]:
            continue
        dominated = np.all(points >= points[i], axis=1) & np.any(points > points[i], axis=1)
        is_efficient &= ~dominated
    return is_efficient


repo_root = find_repo_root()
figures_root = repo_root / "analysis" / "figures"
figures_dir = figures_root / "sim"
figures_dir.mkdir(parents=True, exist_ok=True)

repo_root, figures_dir
# Out:
# (PosixPath('/home/goncalo/KubeEnergyScheduler'),
#  PosixPath('/home/goncalo/KubeEnergyScheduler/analysis/figures/sim'))

# %% [markdown]
# ## 2. Locate experiment artefacts
#
# Both the simulator and the Kubernetes replay export CSV/JSON artefacts. Update the
# paths below if you want to compare different runs.

# %%
# Simulator artefacts (per-job traces  summary metrics)
sim_dir = repo_root / "hetsched" / "results"
sim_summary_path = sim_dir / "summary.csv"

# Kubernetes replay decisions (JSONL  optional CSV projection)
k8_decisions_jsonl = sim_dir / "decisions.jsonl"
k8_decisions_csv = sim_dir / "decisions.csv"

sim_dir, sim_summary_path, k8_decisions_jsonl, k8_decisions_csv
# Out:
# (PosixPath('/home/goncalo/KubeEnergyScheduler/analysis/results'),
#  PosixPath('/home/goncalo/KubeEnergyScheduler/analysis/results/summary.csv'),
#  PosixPath('/home/goncalo/KubeEnergyScheduler/analysis/results/decisions.jsonl'),
#  PosixPath('/home/goncalo/KubeEnergyScheduler/analysis/results/decisions.csv'))

# %% [markdown]
# ## 3. Load simulator traces
#
# The simulator stores one CSV per scheduler/policy configuration with per-job
# records. We consolidate them into a single `DataFrame` and derive the wait/runtime
# features required for the comparisons. The aggregated metrics are loaded from the
# `summary.csv` file emitted at the end of the simulation batch.

# %%
sim_per_job_frames: List[pd.DataFrame] = []

for csv_path in sorted(sim_dir.glob("*_results.csv")):
    if csv_path.name == "summary.csv":
        continue
    df = pd.read_csv(csv_path)
    # Ensure the common schema
    df["submit"] = pd.to_datetime(df["submit"], utc=True, errors="coerce")
    df["start"] = pd.to_datetime(df["start"], utc=True, errors="coerce")
    df["end"] = pd.to_datetime(df["end"], utc=True, errors="coerce")
    df["wait_s"] = df["wait_ms"].astype(float) / 1000.0
    df["runtime_s"] = compute_runtime_seconds(df["start"], df["end"])
    df["source"] = "simulator"

    # Add identifiers extracted from the filename (policy  configuration)
    base_name, ci_weight, batch_size, _ = csv_path.stem.rsplit("_", 3)
    df["policy"] = base_name
    df["ci_weight"] = float(ci_weight)
    df["batch_size"] = int(batch_size)
    sim_per_job_frames.append(df)

sim_per_job = pd.concat(sim_per_job_frames, ignore_index=True)
sim_per_job.head()
# Out:
#           sched   job_id    site      node                    submit  \
# 0  carbonscaler  job-000  site-b  site-b-2 2025-01-01 00:00:00+00:00
# 1  carbonscaler  job-001  site-b  site-b-2 2025-01-01 00:03:00+00:00
# 2  carbonscaler  job-002  site-b  site-b-1 2025-01-01 00:06:00+00:00
# 3  carbonscaler  job-003  site-a  site-a-1 2025-01-01 00:09:00+00:00
# 4  carbonscaler  job-004  site-a  site-a-2 2025-01-01 00:12:00+00:00
#
#                       start                       end  wait_ms   ci_cost  \
# 0 2025-01-01 00:00:00+00:00 2025-01-01 00:30:00+00:00        0  0.014674
# 1 2025-01-01 00:30:00+00:00 2025-01-01 01:00:00+00:00  1620000  0.014674
# 2 2025-01-01 00:30:00+00:00 2025-01-01 00:55:00+00:00  1440000  0.014943
# 3 2025-01-01 00:45:00+00:00 2025-01-01 01:20:00+00:00  2160000  0.134012
# 4 2025-01-01 00:30:00+00:00 2025-01-01 00:50:00+00:00  1080000  0.085249
#
#    wait_s  runtime_s     source        policy  ci_weight  batch_size
# 0     0.0     1800.0  simulator  carbonscaler        0.2        1000
# 1  1620.0     1800.0  simulator  carbonscaler        0.2        1000
# 2  1440.0     1500.0  simulator  carbonscaler        0.2        1000
# 3  2160.0     2100.0  simulator  carbonscaler        0.2        1000
# 4  1080.0     1200.0  simulator  carbonscaler        0.2        1000

# %%
sim_summary = pd.read_csv(sim_summary_path)
sim_summary["source"] = "simulator"
sim_summary
# Out:
#           policy  ci_weight  batch_size  total_ci_cost_g  avg_ci_per_job_g  \
# 0            k8s        0.2        1000         3.350728          0.069807
# 1   carbonscaler        0.2        1000         3.058314          0.063715
# 2      ecokube        0.2        1000         2.854988          0.059479
# 3            k8s        0.2         200         3.350728          0.069807
# 4   carbonscaler        0.2         200         3.058314          0.063715
# 5      ecokube        0.2         200         2.854988          0.059479
# 6            k8s        0.2         500         3.350728          0.069807
# 7   carbonscaler        0.2         500         3.058314          0.063715
# 8      ecokube        0.2         500         2.854988          0.059479
# 9            k8s        0.4        1000         3.350728          0.069807
# 10  carbonscaler        0.4        1000         3.058314          0.063715
# 11     ecokube        0.4        1000         2.854988          0.059479
# 12           k8s        0.4         200         3.350728          0.069807
# 13  carbonscaler        0.4         200         3.058314          0.063715
# 14     ecokube        0.4         200         2.854988          0.059479
# 15           k8s        0.4         500         3.350728          0.069807
# 16  carbonscaler        0.4         500         3.058314          0.063715
# 17     ecokube        0.4         500         2.854988          0.059479
# 18           k8s        0.6        1000         3.350728          0.069807
# 19  carbonscaler        0.6        1000         3.046470          0.063468
# 20     ecokube        0.6        1000         2.854988          0.059479
# 21           k8s        0.6         200         3.350728          0.069807
# 22  carbonscaler        0.6         200         3.046470          0.063468
# 23     ecokube        0.6         200         2.854988          0.059479
# 24           k8s        0.6         500         3.350728          0.069807
# 25  carbonscaler        0.6         500         3.046470          0.063468
# 26     ecokube        0.6         500         2.854988          0.059479
# 27           k8s        0.8        1000         3.350728          0.069807
# 28  carbonscaler        0.8        1000         3.046470          0.063468
# 29     ecokube        0.8        1000         2.854988          0.059479
# 30           k8s        0.8         200         3.350728          0.069807
# 31  carbonscaler        0.8         200         3.046470          0.063468
# 32     ecokube        0.8         200         2.854988          0.059479
# 33           k8s        0.8         500         3.350728          0.069807
# 34  carbonscaler        0.8         500         3.046470          0.063468
# 35     ecokube        0.8         500         2.854988          0.059479
#
#     cfp_g_per_cpu_hour  avg_wait_s  makespan_s  elapsed_ms  num_jobs  \
# 0             0.011462     4320.00     15600.0         1.0        48
# 1             0.010693     2413.75     15000.0         1.0        48
# 2             0.010270     2020.00     14400.0         1.0        48
# 3             0.011462     4320.00     15600.0         1.0        48
# 4             0.010693     2413.75     15000.0         1.0        48
# 5             0.010270     2020.00     14400.0         1.0        48
# 6             0.011462     4320.00     15600.0         1.0        48
# 7             0.010693     2413.75     15000.0         1.0        48
# 8             0.010270     2020.00     14400.0         1.0        48
# 9             0.011462     4320.00     15600.0         1.0        48
# 10            0.010693     2413.75     15000.0         1.0        48
# 11            0.010270     2020.00     14400.0         1.0        48
# 12            0.011462     4320.00     15600.0         1.0        48
# 13            0.010693     2413.75     15000.0         1.0        48
# 14            0.010270     2020.00     14400.0         1.0        48
# 15            0.011462     4320.00     15600.0         1.0        48
# 16            0.010693     2413.75     15000.0         1.0        48
# 17            0.010270     2020.00     14400.0         1.0        48
# 18            0.011462     4320.00     15600.0         1.0        48
# 19            0.010677     2363.75     14700.0         1.0        48
# 20            0.010270     2020.00     14400.0         1.0        48
# 21            0.011462     4320.00     15600.0         1.0        48
# 22            0.010677     2363.75     14700.0         1.0        48
# 23            0.010270     2020.00     14400.0         1.0        48
# 24            0.011462     4320.00     15600.0         2.0        48
# 25            0.010677     2363.75     14700.0         1.0        48
# 26            0.010270     2020.00     14400.0         1.0        48
# 27            0.011462     4320.00     15600.0         1.0        48
# 28            0.010677     2363.75     14700.0         1.0        48
# 29            0.010270     2020.00     14400.0         1.0        48
# 30            0.011462     4320.00     15600.0         1.0        48
# 31            0.010677     2363.75     14700.0         1.0        48
# 32            0.010270     2020.00     14400.0         1.0        48
# 33            0.011462     4320.00     15600.0         1.0        48
# 34            0.010677     2363.75     14700.0         1.0        48
# 35            0.010270     2020.00     14400.0         1.0        48
#
#     alpha_mass  lookahead_min  duration_scale  duration_overrides     source
# 0          1.0              0             1.0                 NaN  simulator
# 1          1.0              0             1.0                 NaN  simulator
# 2          1.0              0             1.0                 NaN  simulator
# 3          1.0              0             1.0                 NaN  simulator
# 4          1.0              0             1.0                 NaN  simulator
# 5          1.0              0             1.0                 NaN  simulator
# 6          1.0              0             1.0                 NaN  simulator
# 7          1.0              0             1.0                 NaN  simulator
# 8          1.0              0             1.0                 NaN  simulator
# 9          1.0              0             1.0                 NaN  simulator
# 10         1.0              0             1.0                 NaN  simulator
# 11         1.0              0             1.0                 NaN  simulator
# 12         1.0              0             1.0                 NaN  simulator
# 13         1.0              0             1.0                 NaN  simulator
# 14         1.0              0             1.0                 NaN  simulator
# 15         1.0              0             1.0                 NaN  simulator
# 16         1.0              0             1.0                 NaN  simulator
# 17         1.0              0             1.0                 NaN  simulator
# 18         1.0              0             1.0                 NaN  simulator
# 19         1.0              0             1.0                 NaN  simulator
# 20         1.0              0             1.0                 NaN  simulator
# 21         1.0              0             1.0                 NaN  simulator
# 22         1.0              0             1.0                 NaN  simulator
# 23         1.0              0             1.0                 NaN  simulator
# 24         1.0              0             1.0                 NaN  simulator
# 25         1.0              0             1.0                 NaN  simulator
# 26         1.0              0             1.0                 NaN  simulator
# 27         1.0              0             1.0                 NaN  simulator
# 28         1.0              0             1.0                 NaN  simulator
# 29         1.0              0             1.0                 NaN  simulator
# 30         1.0              0             1.0                 NaN  simulator
# 31         1.0              0             1.0                 NaN  simulator
# 32         1.0              0             1.0                 NaN  simulator
# 33         1.0              0             1.0                 NaN  simulator
# 34         1.0              0             1.0                 NaN  simulator
# 35         1.0              0             1.0                 NaN  simulator

# %% [markdown]
# ## 4. Load Kubernetes replay decisions
#
# The controller exports one JSONL record per scheduling decision. The snippet below
# filters Kubernetes-native results (`result_type == "kub_result"`), converts the
# timestamps, and derives wait/runtime metrics to mirror the simulator schema.

# %%
k8_decisions = pd.read_json(k8_decisions_jsonl, lines=True)
k8_decisions = k8_decisions.query("result_type == 'kub_result'").copy()

k8_decisions["submit"] = safe_to_datetime(k8_decisions["queued_at"])
k8_decisions["start"] = safe_to_datetime(k8_decisions["started_at"])
k8_decisions["end"] = safe_to_datetime(k8_decisions["ended_at"])

k8_decisions["wait_s"] = compute_wait_seconds(k8_decisions["submit"], k8_decisions["start"])
k8_decisions["runtime_s"] = compute_runtime_seconds(k8_decisions["start"], k8_decisions["end"])

# The replay uses a single scheduler labelled "engine" in this trace.
k8_decisions["policy"] = k8_decisions["scheduler"]
k8_decisions["source"] = "kubernetes"

k8_decisions[[
    "result_id", "scheduler", "job_id", "site", "node", "wait_s", "runtime_s", "fallback", "cost"
]].head()
# Out:
# Empty DataFrame
# Columns: [result_id, scheduler, job_id, site, node, wait_s, runtime_s, fallback, cost]
# Index: []

# %% [markdown]
# ## 5. Harmonise schemas
#
# To compare the two environments we keep only the shared columns and annotate the
# origin. The helper below produces a tidy table that concatenates simulator and
# Kubernetes traces.

# %%
common_cols = [
    "policy", "job_id", "site", "node", "submit", "start", "end",
    "wait_s", "runtime_s", "ci_cost", "source"
]

sim_view = sim_per_job.copy()
if "policy" not in sim_view.columns:
    sim_view["policy"] = sim_view["sched"]
if "sched" in sim_view.columns:
    sim_view = sim_view.drop(columns=["sched"])
for col in ["site", "node"]:
    if col not in sim_view:
        sim_view[col] = pd.NA
sim_view["ci_cost"] = sim_view["ci_cost"].astype(float)

k8_view = k8_decisions.copy()
if "ci_cost" not in k8_view.columns:
    k8_view["ci_cost"] = k8_view.get("cost", 0.0)

combined = pd.concat(
    [sim_view[common_cols], k8_view[common_cols]],
    ignore_index=True,
    sort=False,
)
combined.head()
# Out:
#          policy   job_id    site      node                    submit  \
# 0  carbonscaler  job-000  site-b  site-b-2 2025-01-01 00:00:00+00:00
# 1  carbonscaler  job-001  site-b  site-b-2 2025-01-01 00:03:00+00:00
# 2  carbonscaler  job-002  site-b  site-b-1 2025-01-01 00:06:00+00:00
# 3  carbonscaler  job-003  site-a  site-a-1 2025-01-01 00:09:00+00:00
# 4  carbonscaler  job-004  site-a  site-a-2 2025-01-01 00:12:00+00:00
#
#                       start                       end  wait_s  runtime_s  \
# 0 2025-01-01 00:00:00+00:00 2025-01-01 00:30:00+00:00     0.0     1800.0
# 1 2025-01-01 00:30:00+00:00 2025-01-01 01:00:00+00:00  1620.0     1800.0
# 2 2025-01-01 00:30:00+00:00 2025-01-01 00:55:00+00:00  1440.0     1500.0
# 3 2025-01-01 00:45:00+00:00 2025-01-01 01:20:00+00:00  2160.0     2100.0
# 4 2025-01-01 00:30:00+00:00 2025-01-01 00:50:00+00:00  1080.0     1200.0
#
#     ci_cost     source
# 0  0.014674  simulator
# 1  0.014674  simulator
# 2  0.014943  simulator
# 3  0.134012  simulator
# 4  0.085249  simulator

# %% [markdown]
# ## 6. Summary metrics per environment
#
# The next cells compute aggregate indicators (number of jobs, completion ratio,
# carbon impact, wait time, fallback rate) to sanity-check the two datasets before
# digging into the Pareto analysis.

# %%
def summarise_jobs(df: pd.DataFrame) -> pd.Series:
    completed = df["end"].notna()
    submit = df["submit"].dropna()
    end_times = df.loc[completed, "end"]

    makespan = (end_times.max() - submit.min()).total_seconds() if not end_times.empty and not submit.empty else np.nan

    return pd.Series({
        "jobs": len(df),
        "completed_jobs": int(completed.sum()),
        "completion_ratio": completed.mean() if len(df) else np.nan,
        "fallback_ratio": df.get("fallback", pd.Series(dtype=float)).mean() if "fallback" in df else np.nan,
        "total_ci_cost_g": df["ci_cost"].sum(),
        "avg_ci_per_job_g": df["ci_cost"].mean(),
        "avg_wait_s": df["wait_s"].mean(),
        "avg_runtime_s": df["runtime_s"].mean(),
        "makespan_s": makespan,
    })

summary_by_source = combined.groupby(["source", "policy"]).apply(summarise_jobs).reset_index()
summary_by_source
# Out:
# /tmp/ipykernel_3785154/3002507737.py:20: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   summary_by_source = combined.groupby(["source", "policy"]).apply(summarise_jobs).reset_index()
#       source        policy   jobs  completed_jobs  completion_ratio  \
# 0  simulator  carbonscaler  576.0           576.0               1.0
# 1  simulator     ecokube  576.0           576.0               1.0
# 2  simulator           k8s  576.0           576.0               1.0
#
#    fallback_ratio  total_ci_cost_g  avg_ci_per_job_g  avg_wait_s  \
# 0             NaN        36.628674          0.063591     2388.75
# 1             NaN        34.259856          0.059479     2020.00
# 2             NaN        40.208724          0.069807     4320.00
#
#    avg_runtime_s  makespan_s
# 0         1525.0     15000.0
# 1         1487.5     14400.0
# 2         1575.0     16500.0

# %% [markdown]
# The simulator additionally exposes rich metadata (configuration weights, elapsed
# simulation time) via `summary.csv`. Joining that file with the per-job aggregates
# helps confirm consistency and provides the inputs for the Pareto plot.

# %%
sim_summary_metrics = summary_by_source.query("source == 'simulator'").merge(
    sim_summary,
    on=["policy"],
    how="left",
    suffixes=("_jobs", "_reported"),
)
sim_summary_metrics[[
    "policy",
    "jobs",
    "total_ci_cost_g_jobs",
    "total_ci_cost_g_reported",
    "avg_wait_s_jobs",
    "avg_wait_s_reported",
]]
# Out:
#           policy   jobs  total_ci_cost_g_jobs  total_ci_cost_g_reported  \
# 0   carbonscaler  576.0             36.628674                  3.058314
# 1   carbonscaler  576.0             36.628674                  3.058314
# 2   carbonscaler  576.0             36.628674                  3.058314
# 3   carbonscaler  576.0             36.628674                  3.058314
# 4   carbonscaler  576.0             36.628674                  3.058314
# 5   carbonscaler  576.0             36.628674                  3.058314
# 6   carbonscaler  576.0             36.628674                  3.046470
# 7   carbonscaler  576.0             36.628674                  3.046470
# 8   carbonscaler  576.0             36.628674                  3.046470
# 9   carbonscaler  576.0             36.628674                  3.046470
# 10  carbonscaler  576.0             36.628674                  3.046470
# 11  carbonscaler  576.0             36.628674                  3.046470
# 12     ecokube  576.0             34.259856                  2.854988
# 13     ecokube  576.0             34.259856                  2.854988
# 14     ecokube  576.0             34.259856                  2.854988
# 15     ecokube  576.0             34.259856                  2.854988
# 16     ecokube  576.0             34.259856                  2.854988
# 17     ecokube  576.0             34.259856                  2.854988
# 18     ecokube  576.0             34.259856                  2.854988
# 19     ecokube  576.0             34.259856                  2.854988
# 20     ecokube  576.0             34.259856                  2.854988
# 21     ecokube  576.0             34.259856                  2.854988
# 22     ecokube  576.0             34.259856                  2.854988
# 23     ecokube  576.0             34.259856                  2.854988
# 24           k8s  576.0             40.208724                  3.350728
# 25           k8s  576.0             40.208724                  3.350728
# 26           k8s  576.0             40.208724                  3.350728
# 27           k8s  576.0             40.208724                  3.350728
# 28           k8s  576.0             40.208724                  3.350728
# 29           k8s  576.0             40.208724                  3.350728
# 30           k8s  576.0             40.208724                  3.350728
# 31           k8s  576.0             40.208724                  3.350728
# 32           k8s  576.0             40.208724                  3.350728
# 33           k8s  576.0             40.208724                  3.350728
# 34           k8s  576.0             40.208724                  3.350728
# 35           k8s  576.0             40.208724                  3.350728
#
#     avg_wait_s_jobs  avg_wait_s_reported
# 0           2388.75              2413.75
# 1           2388.75              2413.75
# 2           2388.75              2413.75
# 3           2388.75              2413.75
# 4           2388.75              2413.75
# 5           2388.75              2413.75
# 6           2388.75              2363.75
# 7           2388.75              2363.75
# 8           2388.75              2363.75
# 9           2388.75              2363.75
# 10          2388.75              2363.75
# 11          2388.75              2363.75
# 12          2020.00              2020.00
# 13          2020.00              2020.00
# 14          2020.00              2020.00
# 15          2020.00              2020.00
# 16          2020.00              2020.00
# 17          2020.00              2020.00
# 18          2020.00              2020.00
# 19          2020.00              2020.00
# 20          2020.00              2020.00
# 21          2020.00              2020.00
# 22          2020.00              2020.00
# 23          2020.00              2020.00
# 24          4320.00              4320.00
# 25          4320.00              4320.00
# 26          4320.00              4320.00
# 27          4320.00              4320.00
# 28          4320.00              4320.00
# 29          4320.00              4320.00
# 30          4320.00              4320.00
# 31          4320.00              4320.00
# 32          4320.00              4320.00
# 33          4320.00              4320.00
# 34          4320.00              4320.00
# 35          4320.00              4320.00

# %% [markdown]
# ## 6. Evaluation metrics
#
# We materialise the thesis metrics for carbon- and time-aware evaluation. The code below
# implements the definitions from Section 6.2.2: CFP (6.2), SCI (6.3), makespan (6.4),
# latency (6.5), scheduler overhead and throughput (6.6), and the average energy per job.
# All quantities are normalised per batch/policy so that simulator and Kubernetes traces
# can be compared directly once telemetry is populated.

# %%
# Evaluate thesis metrics (CFP, SCI, makespan, latency, scheduler overhead, throughput, energy/job).
nodes_catalog = pd.read_csv(repo_root / "hetsched" / "config" / "nodes.csv")
sites_catalog = pd.read_csv(repo_root / "hetsched" / "config" / "sites.csv")

node_power_lookup = {}
node_site_lookup = {}
if {"name", "peak_power_w", "site"}.issubset(nodes_catalog.columns):
    node_power_lookup = nodes_catalog.set_index("name")["peak_power_w"].astype(float).to_dict()
    node_site_lookup = nodes_catalog.set_index("name")["site"].to_dict()

site_pue_lookup = {}
if {"id", "pue"}.issubset(sites_catalog.columns):
    site_pue_lookup = sites_catalog.set_index("id")["pue"].astype(float).to_dict()


def compute_evaluation_metrics(frame: pd.DataFrame, fallback_overhead_s: float | None = None) -> pd.Series:
    data = frame.copy()
    if data.empty:
        return pd.Series({
            "jobs_total": 0,
            "jobs_completed": 0,
            "carbon_footprint_g": np.nan,
            "carbon_footprint_kg": np.nan,
            "software_carbon_intensity_g_per_job": np.nan,
            "makespan_s": np.nan,
            "latency_s": np.nan,
            "throughput_jobs_per_hour": np.nan,
            "scheduler_overhead_s": fallback_overhead_s if fallback_overhead_s is not None else np.nan,
            "energy_per_job_wh": np.nan,
        })

    data["submit"] = safe_to_datetime(data["submit"])
    data["start"] = safe_to_datetime(data["start"])
    data["end"] = safe_to_datetime(data["end"])

    if "wait_s" in data.columns:
        data["wait_s"] = data["wait_s"].astype(float)
    else:
        data["wait_s"] = compute_wait_seconds(data["submit"], data["start"])

    if "runtime_s" in data.columns:
        data["runtime_s"] = data["runtime_s"].astype(float)
    else:
        data["runtime_s"] = compute_runtime_seconds(data["start"], data["end"])

    if "ci_cost" in data.columns:
        data["ci_cost"] = data["ci_cost"].astype(float)
    else:
        data["ci_cost"] = 0.0

    completed_mask = data["end"].notna()
    jobs_total = int(len(data))
    jobs_completed = int(completed_mask.sum())

    cfp_total_g = float(data.loc[completed_mask, "ci_cost"].sum())
    sci_g_per_job = cfp_total_g / jobs_completed if jobs_completed else np.nan

    arrival_times = data["submit"].dropna()
    completion_times = data.loc[completed_mask, "end"].dropna()
    if not arrival_times.empty and not completion_times.empty:
        makespan_s = (completion_times.max() - arrival_times.min()).total_seconds()
    else:
        makespan_s = np.nan

    latency_s = float(data["wait_s"].mean()) if len(data["wait_s"]) else np.nan

    if jobs_completed and pd.notna(makespan_s) and makespan_s > 0:
        throughput_jobs_per_hour = jobs_completed / (makespan_s / 3600.0)
    else:
        throughput_jobs_per_hour = np.nan

    energy_series = None
    for candidate in ("energy_wh", "job_energy_wh"):
        if candidate in data.columns:
            energy_series = data.loc[completed_mask, candidate].astype(float)
            break

    if energy_series is None:
        estimates = []
        for idx, row in data.loc[completed_mask].iterrows():
            node = row.get("node")
            runtime_s = row.get("runtime_s")
            power_w = node_power_lookup.get(node)
            if power_w is None or pd.isna(runtime_s) or runtime_s <= 0:
                estimates.append(np.nan)
                continue
            site_id = node_site_lookup.get(node)
            pue = site_pue_lookup.get(site_id, 1.0)
            estimates.append(power_w * pue * (runtime_s / 3600.0))
        if estimates:
            energy_series = pd.Series(estimates, index=data.loc[completed_mask].index, dtype=float)

    if energy_series is not None and energy_series.notna().any():
        total_energy_wh = float(energy_series.dropna().sum())
        energy_per_job_wh = total_energy_wh / jobs_completed if jobs_completed else np.nan
    else:
        energy_per_job_wh = np.nan

    if "scheduler_latency_s" in data.columns:
        scheduler_overhead_s = float(data["scheduler_latency_s"].astype(float).mean())
    elif "scheduler_latency_ms" in data.columns:
        scheduler_overhead_s = float(data["scheduler_latency_ms"].astype(float).mean() / 1000.0)
    elif fallback_overhead_s is not None:
        scheduler_overhead_s = float(fallback_overhead_s)
    else:
        scheduler_overhead_s = np.nan

    return pd.Series({
        "jobs_total": jobs_total,
        "jobs_completed": jobs_completed,
        "carbon_footprint_g": cfp_total_g,
        "carbon_footprint_kg": cfp_total_g / 1000.0 if pd.notna(cfp_total_g) else np.nan,
        "software_carbon_intensity_g_per_job": sci_g_per_job,
        "makespan_s": makespan_s,
        "latency_s": latency_s,
        "throughput_jobs_per_hour": throughput_jobs_per_hour,
        "scheduler_overhead_s": scheduler_overhead_s,
        "energy_per_job_wh": energy_per_job_wh,
    })


sim_overhead_lookup = {}
if not sim_summary.empty:
    temp = sim_summary.copy()
    temp["scheduler_overhead_s"] = (
        temp["elapsed_ms"].astype(float)
        / temp["num_jobs"].astype(float).clip(lower=1.0)
        / 1000.0
    )
    sim_overhead_lookup = temp.set_index(["policy", "ci_weight", "batch_size"])["scheduler_overhead_s"].to_dict()

metrics_rows = []
for (policy, ci_weight, batch_size), group in sim_per_job.groupby(["policy", "ci_weight", "batch_size"], dropna=False):
    fallback = sim_overhead_lookup.get((policy, ci_weight, batch_size))
    metrics = compute_evaluation_metrics(group, fallback_overhead_s=fallback)
    record = metrics.to_dict()
    record.update({
        "source": "simulator",
        "policy": policy,
        "ci_weight": ci_weight,
        "batch_size": batch_size,
    })
    metrics_rows.append(record)

if not k8_decisions.empty:
    if "ci_weight" not in k8_decisions.columns and "theta_c" in k8_decisions.columns:
        k8_decisions = k8_decisions.copy()
        k8_decisions["ci_weight"] = k8_decisions["theta_c"].astype(float)
    for (policy, ci_weight), group in k8_decisions.groupby(["policy", "ci_weight"], dropna=False):
        metrics = compute_evaluation_metrics(group)
        record = metrics.to_dict()
        record.update({
            "source": "kubernetes",
            "policy": policy,
            "ci_weight": ci_weight,
            "batch_size": group.get("batch_size", pd.Series([pd.NA])).iloc[0] if "batch_size" in group else pd.NA,
        })
        metrics_rows.append(record)

evaluation_metrics = pd.DataFrame(metrics_rows)

if not evaluation_metrics.empty:
    ordered_columns = [
        "source",
        "policy",
        "ci_weight",
        "batch_size",
        "jobs_total",
        "jobs_completed",
        "carbon_footprint_g",
        "carbon_footprint_kg",
        "software_carbon_intensity_g_per_job",
        "makespan_s",
        "latency_s",
        "throughput_jobs_per_hour",
        "scheduler_overhead_s",
        "energy_per_job_wh",
    ]
    evaluation_metrics = evaluation_metrics[ordered_columns].sort_values([
        "source",
        "policy",
        "ci_weight",
        "batch_size",
    ])

evaluation_metrics
# Out:
#        source        policy  ci_weight  batch_size  jobs_total  \
# 0   simulator  carbonscaler        0.2         200        48.0
# 1   simulator  carbonscaler        0.2         500        48.0
# 2   simulator  carbonscaler        0.2        1000        48.0
# 3   simulator  carbonscaler        0.4         200        48.0
# 4   simulator  carbonscaler        0.4         500        48.0
# 5   simulator  carbonscaler        0.4        1000        48.0
# 6   simulator  carbonscaler        0.6         200        48.0
# 7   simulator  carbonscaler        0.6         500        48.0
# 8   simulator  carbonscaler        0.6        1000        48.0
# 9   simulator  carbonscaler        0.8         200        48.0
# 10  simulator  carbonscaler        0.8         500        48.0
# 11  simulator  carbonscaler        0.8        1000        48.0
# 12  simulator     ecokube        0.2         200        48.0
# 13  simulator     ecokube        0.2         500        48.0
# 14  simulator     ecokube        0.2        1000        48.0
# 15  simulator     ecokube        0.4         200        48.0
# 16  simulator     ecokube        0.4         500        48.0
# 17  simulator     ecokube        0.4        1000        48.0
# 18  simulator     ecokube        0.6         200        48.0
# 19  simulator     ecokube        0.6         500        48.0
# 20  simulator     ecokube        0.6        1000        48.0
# 21  simulator     ecokube        0.8         200        48.0
# 22  simulator     ecokube        0.8         500        48.0
# 23  simulator     ecokube        0.8        1000        48.0
# 24  simulator           k8s        0.2         200        48.0
# 25  simulator           k8s        0.2         500        48.0
# 26  simulator           k8s        0.2        1000        48.0
# 27  simulator           k8s        0.4         200        48.0
# 28  simulator           k8s        0.4         500        48.0
# 29  simulator           k8s        0.4        1000        48.0
# 30  simulator           k8s        0.6         200        48.0
# 31  simulator           k8s        0.6         500        48.0
# 32  simulator           k8s        0.6        1000        48.0
# 33  simulator           k8s        0.8         200        48.0
# 34  simulator           k8s        0.8         500        48.0
# 35  simulator           k8s        0.8        1000        48.0
#
#     jobs_completed  carbon_footprint_g  carbon_footprint_kg  \
# 0             48.0            3.058311             0.003058
# 1             48.0            3.058311             0.003058
# 2             48.0            3.058311             0.003058
# 3             48.0            3.058311             0.003058
# 4             48.0            3.058311             0.003058
# 5             48.0            3.058311             0.003058
# 6             48.0            3.046468             0.003046
# 7             48.0            3.046468             0.003046
# 8             48.0            3.046468             0.003046
# 9             48.0            3.046468             0.003046
# 10            48.0            3.046468             0.003046
# 11            48.0            3.046468             0.003046
# 12            48.0            2.854988             0.002855
# 13            48.0            2.854988             0.002855
# 14            48.0            2.854988             0.002855
# 15            48.0            2.854988             0.002855
# 16            48.0            2.854988             0.002855
# 17            48.0            2.854988             0.002855
# 18            48.0            2.854988             0.002855
# 19            48.0            2.854988             0.002855
# 20            48.0            2.854988             0.002855
# 21            48.0            2.854988             0.002855
# 22            48.0            2.854988             0.002855
# 23            48.0            2.854988             0.002855
# 24            48.0            3.350727             0.003351
# 25            48.0            3.350727             0.003351
# 26            48.0            3.350727             0.003351
# 27            48.0            3.350727             0.003351
# 28            48.0            3.350727             0.003351
# 29            48.0            3.350727             0.003351
# 30            48.0            3.350727             0.003351
# 31            48.0            3.350727             0.003351
# 32            48.0            3.350727             0.003351
# 33            48.0            3.350727             0.003351
# 34            48.0            3.350727             0.003351
# 35            48.0            3.350727             0.003351
#
#     software_carbon_intensity_g_per_job  makespan_s  latency_s  \
# 0                              0.063715     15000.0    2413.75
# 1                              0.063715     15000.0    2413.75
# 2                              0.063715     15000.0    2413.75
# 3                              0.063715     15000.0    2413.75
# 4                              0.063715     15000.0    2413.75
# 5                              0.063715     15000.0    2413.75
# 6                              0.063468     14700.0    2363.75
# 7                              0.063468     14700.0    2363.75
# 8                              0.063468     14700.0    2363.75
# 9                              0.063468     14700.0    2363.75
# 10                             0.063468     14700.0    2363.75
# 11                             0.063468     14700.0    2363.75
# 12                             0.059479     14400.0    2020.00
# 13                             0.059479     14400.0    2020.00
# 14                             0.059479     14400.0    2020.00
# 15                             0.059479     14400.0    2020.00
# 16                             0.059479     14400.0    2020.00
# 17                             0.059479     14400.0    2020.00
# 18                             0.059479     14400.0    2020.00
# 19                             0.059479     14400.0    2020.00
# 20                             0.059479     14400.0    2020.00
# 21                             0.059479     14400.0    2020.00
# 22                             0.059479     14400.0    2020.00
# 23                             0.059479     14400.0    2020.00
# 24                             0.069807     16500.0    4320.00
# 25                             0.069807     16500.0    4320.00
# 26                             0.069807     16500.0    4320.00
# 27                             0.069807     16500.0    4320.00
# 28                             0.069807     16500.0    4320.00
# 29                             0.069807     16500.0    4320.00
# 30                             0.069807     16500.0    4320.00
# 31                             0.069807     16500.0    4320.00
# 32                             0.069807     16500.0    4320.00
# 33                             0.069807     16500.0    4320.00
# 34                             0.069807     16500.0    4320.00
# 35                             0.069807     16500.0    4320.00
#
#     throughput_jobs_per_hour  scheduler_overhead_s  energy_per_job_wh
# 0                  11.520000              0.000021           262.6250
# 1                  11.520000              0.000021           262.6250
# 2                  11.520000              0.000021           262.6250
# 3                  11.520000              0.000021           262.6250
# 4                  11.520000              0.000021           262.6250
# 5                  11.520000              0.000021           262.6250
# 6                  11.755102              0.000021           262.6250
# 7                  11.755102              0.000021           262.6250
# 8                  11.755102              0.000021           262.6250
# 9                  11.755102              0.000021           262.6250
# 10                 11.755102              0.000021           262.6250
# 11                 11.755102              0.000021           262.6250
# 12                 12.000000              0.000021           253.2500
# 13                 12.000000              0.000021           253.2500
# 14                 12.000000              0.000021           253.2500
# 15                 12.000000              0.000021           253.2500
# 16                 12.000000              0.000021           253.2500
# 17                 12.000000              0.000021           253.2500
# 18                 12.000000              0.000021           253.2500
# 19                 12.000000              0.000021           253.2500
# 20                 12.000000              0.000021           253.2500
# 21                 12.000000              0.000021           253.2500
# 22                 12.000000              0.000021           253.2500
# 23                 12.000000              0.000021           253.2500
# 24                 10.472727              0.000021           279.6875
# 25                 10.472727              0.000021           279.6875
# 26                 10.472727              0.000021           279.6875
# 27                 10.472727              0.000021           279.6875
# 28                 10.472727              0.000021           279.6875
# 29                 10.472727              0.000021           279.6875
# 30                 10.472727              0.000021           279.6875
# 31                 10.472727              0.000042           279.6875
# 32                 10.472727              0.000021           279.6875
# 33                 10.472727              0.000021           279.6875
# 34                 10.472727              0.000021           279.6875
# 35                 10.472727              0.000021           279.6875

# %% [markdown]
# ### Scheduler decision mix
#
# Aggregate the number of scheduling decisions by policy and environment to verify the replay covers the intended scenarios.

# %%
decision_counts = (
    combined.groupby(["source", "policy"], dropna=False)["job_id"]
    .count()
    .reset_index(name="decisions")
)

if decision_counts.empty:
    decision_counts
else:
    pivot_counts = (
        decision_counts
        .pivot(index="policy", columns="source", values="decisions")
        .fillna(0)
        .sort_index()
    )
    fig, ax = plt.subplots(figsize=(8, 5))
    pivot_counts.plot(kind="bar", ax=ax)
    ax.set_ylabel("Decisions")
    ax.set_title("Scheduler decisions by source")
    ax.legend(title="Source")
    fig.tight_layout()
    decisions_plot_path = figures_dir / "scheduler_decisions_by_source.png"
    fig.savefig(decisions_plot_path, dpi=300)
    pivot_counts, decisions_plot_path

# %% [markdown]
# ## 7. Visual comparisons
#
# We now contrast the average wait times and carbon footprint of each policy. The
# Kubernetes replay (engine) is highlighted separately; because the sampled trace only
# contains fallback decisions, the wait/runtime metrics stay undefined (`NaN`).

# %%
fig, ax = plt.subplots(figsize=(8, 5))

sim_points = sim_summary_metrics.sort_values("total_ci_cost_g_reported")
ax.scatter(
    sim_points["total_ci_cost_g_reported"],
    sim_points["avg_wait_s_reported"],
    label="Simulator policies",
    c="tab:blue",
)
for _, row in sim_points.iterrows():
    ax.annotate(
        row["policy"],
        (row["total_ci_cost_g_reported"], row["avg_wait_s_reported"]),
        textcoords="offset points",
        xytext=(5, 5),
    )

k8_summary = summary_by_source.query("source == 'kubernetes'")
if not k8_summary.empty:
    ax.scatter(
        k8_summary["total_ci_cost_g"],
        k8_summary["avg_wait_s"],
        label="Kubernetes replay",
        marker="s",
        c="tab:orange",
        s=90,
    )
    for _, row in k8_summary.iterrows():
        ax.annotate(
            f"k8s:{row['policy']}",
            (row["total_ci_cost_g"], row["avg_wait_s"]),
            textcoords="offset points",
            xytext=(5, -12),
        )

ax.set_xlabel("Total CI cost (g)")
ax.set_ylabel("Average wait (s)")
ax.set_title("Carbon vs. wait trade-offs")
ax.legend()
fig.tight_layout()

tradeoff_path = figures_dir / "carbon_vs_wait_tradeoff.png"
fig.savefig(tradeoff_path, dpi=300)
tradeoff_path
# Out:
# PosixPath('/home/goncalo/KubeEnergyScheduler/analysis/figures/sim/carbon_vs_wait_tradeoff.png')

# %% [markdown]
# ## 8. Pareto-front analysis
#
# The Pareto filter isolates the policies that are non-dominated with respect to
# (total carbon, average wait). These are the options worth keeping when searching
# for better baselines or new algorithms.

# %%
pareto_metrics = sim_points[["total_ci_cost_g_reported", "avg_wait_s_reported"]].to_numpy()
mask = pareto_front(pareto_metrics)
pareto_candidates = sim_points.loc[mask].copy()
pareto_candidates
# Out:
#    source_jobs     policy   jobs  completed_jobs  completion_ratio  \
# 12   simulator  ecokube  576.0           576.0               1.0
# 13   simulator  ecokube  576.0           576.0               1.0
# 14   simulator  ecokube  576.0           576.0               1.0
# 15   simulator  ecokube  576.0           576.0               1.0
# 19   simulator  ecokube  576.0           576.0               1.0
# 18   simulator  ecokube  576.0           576.0               1.0
# 17   simulator  ecokube  576.0           576.0               1.0
# 16   simulator  ecokube  576.0           576.0               1.0
# 23   simulator  ecokube  576.0           576.0               1.0
# 22   simulator  ecokube  576.0           576.0               1.0
# 21   simulator  ecokube  576.0           576.0               1.0
# 20   simulator  ecokube  576.0           576.0               1.0
#
#     fallback_ratio  total_ci_cost_g_jobs  avg_ci_per_job_g_jobs  \
# 12             NaN             34.259856               0.059479
# 13             NaN             34.259856               0.059479
# 14             NaN             34.259856               0.059479
# 15             NaN             34.259856               0.059479
# 19             NaN             34.259856               0.059479
# 18             NaN             34.259856               0.059479
# 17             NaN             34.259856               0.059479
# 16             NaN             34.259856               0.059479
# 23             NaN             34.259856               0.059479
# 22             NaN             34.259856               0.059479
# 21             NaN             34.259856               0.059479
# 20             NaN             34.259856               0.059479
#
#     avg_wait_s_jobs  avg_runtime_s  ...  cfp_g_per_cpu_hour  \
# 12           2020.0         1487.5  ...             0.01027
# 13           2020.0         1487.5  ...             0.01027
# 14           2020.0         1487.5  ...             0.01027
# 15           2020.0         1487.5  ...             0.01027
# 19           2020.0         1487.5  ...             0.01027
# 18           2020.0         1487.5  ...             0.01027
# 17           2020.0         1487.5  ...             0.01027
# 16           2020.0         1487.5  ...             0.01027
# 23           2020.0         1487.5  ...             0.01027
# 22           2020.0         1487.5  ...             0.01027
# 21           2020.0         1487.5  ...             0.01027
# 20           2020.0         1487.5  ...             0.01027
#
#     avg_wait_s_reported  makespan_s_reported  elapsed_ms  num_jobs  \
# 12               2020.0              14400.0         1.0        48
# 13               2020.0              14400.0         1.0        48
# 14               2020.0              14400.0         1.0        48
# 15               2020.0              14400.0         1.0        48
# 19               2020.0              14400.0         1.0        48
# 18               2020.0              14400.0         1.0        48
# 17               2020.0              14400.0         1.0        48
# 16               2020.0              14400.0         1.0        48
# 23               2020.0              14400.0         1.0        48
# 22               2020.0              14400.0         1.0        48
# 21               2020.0              14400.0         1.0        48
# 20               2020.0              14400.0         1.0        48
#
#     alpha_mass  lookahead_min  duration_scale  duration_overrides  \
# 12         1.0              0             1.0                 NaN
# 13         1.0              0             1.0                 NaN
# 14         1.0              0             1.0                 NaN
# 15         1.0              0             1.0                 NaN
# 19         1.0              0             1.0                 NaN
# 18         1.0              0             1.0                 NaN
# 17         1.0              0             1.0                 NaN
# 16         1.0              0             1.0                 NaN
# 23         1.0              0             1.0                 NaN
# 22         1.0              0             1.0                 NaN
# 21         1.0              0             1.0                 NaN
# 20         1.0              0             1.0                 NaN
#
#     source_reported
# 12        simulator
# 13        simulator
# 14        simulator
# 15        simulator
# 19        simulator
# 18        simulator
# 17        simulator
# 16        simulator
# 23        simulator
# 22        simulator
# 21        simulator
# 20        simulator
#
# [12 rows x 25 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 5))

ax.scatter(
    sim_points["total_ci_cost_g_reported"],
    sim_points["avg_wait_s_reported"],
    color="lightgray",
    label="All policies",
)
ax.scatter(
    pareto_candidates["total_ci_cost_g_reported"],
    pareto_candidates["avg_wait_s_reported"],
    color="tab:green",
    label="Pareto front",
)
ax.plot(
    pareto_candidates["total_ci_cost_g_reported"],
    pareto_candidates["avg_wait_s_reported"],
    color="tab:green",
    linestyle="--",
    linewidth=1,
)
for _, row in pareto_candidates.iterrows():
    ax.annotate(
        row["policy"],
        (row["total_ci_cost_g_reported"], row["avg_wait_s_reported"]),
        textcoords="offset points",
        xytext=(4, 6),
    )

ax.set_xlabel("Total CI cost (g)")
ax.set_ylabel("Average wait (s)")
ax.set_title("Simulator Pareto front")
ax.legend()
fig.tight_layout()

pareto_path = figures_dir / "simulator_pareto_front.png"
fig.savefig(pareto_path, dpi=300)
pareto_path
# Out:
# PosixPath('/home/goncalo/KubeEnergyScheduler/analysis/figures/sim/simulator_pareto_front.png')

# %%
tables_dir = repo_root / "analysis" / "tables"
tables_dir.mkdir(parents=True, exist_ok=True)

pareto_latex_path = tables_dir / "pareto_front.tex"
if pareto_candidates.empty:
    pareto_latex_path.write_text("% Pareto front empty\n")
else:
    pareto_candidates.to_latex(
        pareto_latex_path,
        index=False,
        float_format="%.3f",
        caption="Pareto front across simulator policies (carbon vs. wait).",
        label="tab:pareto_front",
    )
pareto_latex_path
# Out:
# PosixPath('/home/goncalo/KubeEnergyScheduler/analysis/tables/pareto_front.tex')

# %% [markdown]
# ## 9. Hooks for contextual metrics (optional)
#
# The design document suggests extending the notebook with contextual indicators
# (power traces, forecasts). When Prometheus endpoints become available, inject the
# queries here and join on the `submit/start/end` timestamps stored in `combined`.

# %% [markdown]
# ## 10. Conclusions
#
# The consolidated tables confirm that the simulator emits complete traces for all
# policies, whereas the sampled Kubernetes replay currently falls back on every job.
# That discrepancy highlights the need for additional cluster-side debugging before
# using the replay as a baseline. The Pareto front nonetheless identifies the
# non-dominated simulator policies, informing which schedulers to evolve or replace
# when collecting new baselines.
